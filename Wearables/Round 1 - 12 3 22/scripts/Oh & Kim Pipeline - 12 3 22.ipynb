# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

import gensim
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
#nltk.download()
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
dictionary_words = set(nltk.corpus.words.words())

from pprint import pprint

from textblob import TextBlob, Word

import spacy
import spacy_legacy
#loading the english language small model of spacy
en = spacy.load('en_core_web_sm')
sw_spacy = en.Defaults.stop_words


import pickle
import re 
import pyLDAvis
import pyLDAvis.gensim_models

import itertools 
#custom list of stop words
stop_words_english = []
with open('stop_words_english.txt', encoding="utf8") as my_file:
    for line in my_file:
        stop_words_english.append(line.replace("\n", ""))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Wahbeh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Wahbeh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv ('SampleReviews.csv')

# %%
df.shape
# Out:
# (1000, 1)

# %%
df
# Out:
#                                              Full Text
# 0    My nephew loves h8s new apple watch. The fact ...
# 1    The Apple Watch Series 6 has so many amazing f...
# 2    Replaced my Apple Watch with this gem. I like ...
# 3    My old Apple Watch stopped charging and I was ...
# 4    I’m super pleased with these chargers. They wo...
# ..                                                 ...
# 995  Love my Apple Watch! I get all my notification...
# 996  Perfect fit easy Install very durable comparab...
# 997  This is my 4th sport loop for apple watch I ow...
# 998  I was surprised at how much I actually interac...
# 999  Finally purchased my first Apple Watch. Works ...
#
# [1000 rows x 1 columns]

# %%
df= df.apply(lambda x: x.astype(str).str.lower())

# %%
df.head()
# Out:
#                                            Full Text
# 0  my nephew loves h8s new apple watch. the fact ...
# 1  the apple watch series 6 has so many amazing f...
# 2  replaced my apple watch with this gem. i like ...
# 3  my old apple watch stopped charging and i was ...
# 4  i’m super pleased with these chargers. they wo...

# %% [markdown]
# # Caclualte Bigrams Frequencies to Identofy Wearables Quality Dimensions:

# %%
reviews = np.array(df['Full Text'])
reviews = ' '.join(reviews)
#reviews

# %%
def clean_text(reviews):
    reviews = re.sub(r'[^\w\s]','', reviews) #remove punctuation marks and special chars
    reviews = re.sub('[^A-Za-z0-9]+', ' ', reviews) #remove anything that is not a number or or letter
    reviews = re.sub('[\W_]', ' ', reviews) #Remove any thing excpet charcater and alphanumeric words
    reviews = re.sub(r'\w*\d\w*', '', reviews) #Remove any thing with numbers
    reviews = ' '.join(word for word in reviews.split() if not word.isdigit())

    #remove words that consists of less than three letter
    words = [word for word in reviews.split() if len(word)>2]
    reviews = " ".join(words)

    #Remove stop words using custom list of stop words
    words = [word for word in reviews.split() if word.lower() not in stop_words_english]
    reviews = " ".join(words)

    #Remove brands related keywords
    brands = ["fitbit ace", "fitbit charge", "fitbit verca", "fitbit ionic",  "fitbit versa lite",  
              "fitbit inspire",  "fitbit versa",  "garmin forerunner",  "garmin fēnix",  "garmin vívoki",  
              "garmin vívofit",  "garmin vívoactive",  "garmin vívomove",  "garmin vívosmart",  
              "garmin vívosport",  "garmin venu",  "garmin instinct",  "garmin luxe",  "garmin darth vader",  
              "garmin captain marvel",  "garmin approach",  "garmin lily",  "garmin swim",  "xiaomi mi band",  
              "xiaomi mi samrt band",  "moov now",  "moov hr",  "apple watch",  "fossil gen",  
              "fossil sport smartwatch",  "fossil hybrid smartwatch hr",  "misfit vap, ",  "misfit ray",  
              "misfit path",  "misfit command",  "withings steel",  "withings move",  "withings pulds",  
              "withings move ecg",  "ihealth watch",  "samsung gear",  "samsung galaxy watch active",  
              "samsung galaxy fit",  "polar a360",  "polar a370",  "polar m430",  "polar m200",  "polar h10",  
              "polar vantage",  "polar ignite",  "polar grit x",  "polar titan",  "polar oh1",  "polar h9",  
              "striiv fusion",  "striiv apex hr",  "striiv dash hr",  "huawei talkband",  " huawei watch",  
              "huawei band",  "mykronoz zewatch",  "mykronoz zefit",  "mykronoz zesport",  "mykronoz zetime",  
              "mykronoz zefit",  "mykronoz zeround",  "mykronoz zeneo",  "mykronoz zetrack",  "coros apex",  
              "wyze band",  "letsfit fitness racker",  "coros pace",  "withings scanwatch",  "amazon halo",  
              "timex ironman",  "suunto peak",  "wahoo fitness", "fitbit", "garmin", "apple", "xiaomi", "moov",
              "fossil", "misfit", "withings", "ihealth", "samsung", "polar", "striiv", "huawei", "mykronoz", 
              "coros", "wyze", "letsfit", "amazon"]

    resultwords  = [word for word in reviews.split() if word.lower() not in brands]
    reviews = ' '.join(resultwords)


    #Remove category-related words
    categories = ["watch", "watches", "smart watch", "smartwatch", "band", "bands", "smartband", 
                  "smart band", "smartbands", "smart bands", "case", "cases", "cover", "protective", 
                  "protector", "screen", "show", "iphone", "express", "appleevent", "shield", 
                  "show", "appltv", "gear vr", "tv", "shoe", "mountain", "mountains", "beach", 
                  "appltv", "accessory", "accessories"]

    resultwords  = [word for word in reviews.split() if word.lower() not in categories]
    reviews = ' '.join(resultwords)


    #Remove feature-related words
    features = ["ability", "quality", "feature", "aspect", "abilities", "qualities", "features", "aspects"]
    resultwords  = [word for word in reviews.split() if word.lower() not in features]
    reviews = ' '.join(resultwords)
    
    return reviews

# %%
reviews = clean_text(reviews)

# %%
text_file = open("processedreviews.txt", "w")
text_file.write(reviews)
text_file.close()

# %% [markdown]
# # Open Processed Reviews

# %%
with open("processedreviews.txt","r") as f:
    reviews = f.read()

# %%
reviews
# Out:
# 'nephew loves fact waterproof finding black friday deal buys series amazing health readings attention replaced gem durability battery life day hunt stopped charging bummed buy glad faster clear super pleased chargers work great versa price chargers highly recommend buying excellent space gray serves great leaves access switch easily wifes lasted years great hoping years husband wanted airy wear working garden likes lot love everyday learn wanted needed lot money item perfect imagine spending true love love love big game changer notes ipad bought relative series love enjoying learning bought needed sport bought cheaper fell broke bought trusted brand forerunner gps heart rate monitor running black excellent convenient heath wellness versa great affordable attractive love stylish exercises heart rate burning calories loved price compared watchesnneven previous generation functions versa wanted large display menu options color salesman patient friendly knowledgeable wanted love watchnthank buy love easy wear velco closure stays tightly closed bought series fits perfectly charges capacity issues longer cord regular charger bit length love love color upgraded addition wear day recharge nike series wanted match fits perfectly nike face sharp comfortable ive ordered miscellaneous venders charge purchased charge returned charge uncomfortable wear broke track sleep didnt work keeping track runs junk wont charge phone pro charge series nike edition wont work phone disappointed charger doesnt work fit rubber sleeve charge completely defeats purpose purchase love charge connection broke glued plastic piece taped electricians tape hey android pretty fair purchase product work dont recommend buying honestly received charger worth time return bought hope kind bummer rapticedge bumper protect functioning optimally difficulty accessing apps nice fit series stay locked loose returned bumper protected scratch bumped work fits perfectly stuff alittle market mach stretch great life mate products hard connect charge phone list phones compatible days faded bad hoping luck ended returning connect airpods worked great fits nice charge month corners start lift reseal eventually start lifting idea convenient house worry bringing phone room room love smart display loved battery lasted bit longer coming versa lite love accurate shower personally dont highly recommend browser support video fan years iphones ipads air pods fan goodjust good watchwe works wellhavent issue yetnot oneits charge advanced charge place arrives trick love imagine living everyday finding awesome wearable owned enjoyed series lot responsive works greatest happy phone easy attach secure wrist nwears comfortable easy attach easily fastened gen upgrades ecg nice accurate good nicely built worth price bad works perfectly fine nits newest save money neasy setup love bought gift wifes birthday price range battery life wife loves love pay oxygen level love track miles walk adjusting face liking changing wristbands easy loved quick easy order process sell price easy motivated excellent gift love itneasy paired phone versa read news track exercise routine diet easy metal easier cool device size perfect size small newer releases love pink brighter dirty compared amazing pleased love prices buy love buy buy price sells doubt difference purchased wife loves comfortable likes size compared charge great bought wife loves works great suppose battery life good love product waych pretty barely ordered online ready hour associate brought car love helps fitness airpods airpods perfect cute buy happy waited purchase years generation excellent product type series easy clean soap water love adjusting easy light cooler summer months bought open box live bought runs stays connected phone purchased gift timely person received check ekg life saver smart love fantastic huge beautiful funcional love inspire moving making great progress helping lose weightit great price finally talked loves durable dont phone w ...

# %%
tokens = nltk.word_tokenize(reviews)

#Create your bigrams
bgs = nltk.bigrams(tokens)

#compute frequency distribution for all the bigrams in the text
fdist = nltk.FreqDist(bgs)
# for k,v in fdist.items():
#     print(k,v)

# %%
df1 = pd.DataFrame(fdist.items())
df1.columns = ['Bigrams', 'Frequencies']
df1.sort_values(by=['Frequencies'], ascending=False).head()
# Out:
#                   Bigrams  Frequencies
# 17        (battery, life)           51
# 36    (highly, recommend)           35
# 484        (works, great)           32
# 74           (love, love)           18
# 1022        (great, love)           17

# %%
df2 = df1.loc[df1['Frequencies'] >= 10]
df2.sort_values(by=['Frequencies'], ascending=False)
# Out:
#                   Bigrams  Frequencies
# 17        (battery, life)           51
# 36    (highly, recommend)           35
# 484        (works, great)           32
# 74           (love, love)           18
# 99          (heart, rate)           17
# 1022        (great, love)           17
# 1315     (great, product)           17
# 804    (absolutely, love)           14
# 562        (great, price)           13
# 150     (fits, perfectly)           12
# 656    (upgraded, series)           11
# 409         (wife, loves)           10
# 779        (love, series)           10

# %%
df2.to_csv('TopFrequentBigrams.csv', index=False)

# %% [markdown]
# # Identify Keywords with Negators and Remove Review

# %%
from re import split
def split_string(string, delimiters):
    string = string.replace(".", "," ) 
    string = string.replace("?", "," )
    pattern = r'|'.join(delimiters)
    return split(pattern, string)

# %%
r = "Python is fun. The string is for test because python run the code once you execute it"

#conjunctions and punctuations are based on the Buschken paper, excpet the '(' and ')'
d = ['& ', ', ','; ','! ',': ','for ','and ', 'but ', 'or ', 'so ',
     'after ', 'as ', 'because ', 'before ', 'even ', 'if ', 'now ', 'once ', 
     'since ', 'than ', 'that ', 'thought ', 'when ', 'where ', 'which ', 
     'while ', 'who ', 'what ']

new_string = split_string(r, d)
print(new_string)
# Out:
# ['Python is fun', 'The string is ', 'test ', 'python run the code ', 'you execute it']

# %%
#custom list of stop words without conjunctions
stop_words_english = []
with open('stop_words_english_conjunctions_negations.txt', encoding="utf8") as my_file:
    for line in my_file:
        stop_words_english.append(line.replace("\n", ""))

# %%
def clean_text(docs):
    for i in range(len(docs)):
        #remove hashtags and mentions
        docs[i] = " ".join(filter(lambda x:x[0]!='#', docs[i].split())) #remove hashtags
        docs[i] = " ".join(filter(lambda x:x[0]!='@', docs[i].split())) #remove mentiones
        
        #remove special chars, anything not a number or letter, anything excpet alphanumeric words
        docs[i] = re.sub(r'[^\w\s]','',docs[i]) #remove punctuation marks and special chars
        docs[i] = re.sub('[^A-Za-z0-9]+', ' ', docs[i]) #remove anything that is not a number or or letter
        docs[i] = re.sub('[\W_]', ' ', docs[i]) #Remove any thing excpet charcater and alphanumeric words
        docs[i] = re.sub(r'\w*\d\w*', '', docs[i]) #Remove any thing with numbers
        docs[i] = ' '.join(word for word in docs[i].split() if not word.isdigit())
        
        #compare words to englisg dictionary and remove nonsense words
        words = [word for word in docs[i].split() if word.lower() in dictionary_words or not word.isalpha()]
        docs[i] = " ".join(words)
        
        #remove words that consists of less than three letter
        words = [word for word in docs[i].split() if len(word)>2]
        docs[i] = " ".join(words)
                             
        #Remove stop words using custom list of stop words
        words = [word for word in reviews[i].split() if word.lower() not in stop_words_english]
        reviews[i] = " ".join(words)

        #Remove brands related keywords
        brands = ["fitbit ace", "fitbit charge", "fitbit verca", "fitbit ionic",  "fitbit versa lite",  
                  "fitbit inspire",  "fitbit versa",  "garmin forerunner",  "garmin fēnix",  "garmin vívoki",  
                  "garmin vívofit",  "garmin vívoactive",  "garmin vívomove",  "garmin vívosmart",  
                  "garmin vívosport",  "garmin venu",  "garmin instinct",  "garmin luxe",  "garmin darth vader",  
                  "garmin captain marvel",  "garmin approach",  "garmin lily",  "garmin swim",  "xiaomi mi band",  
                  "xiaomi mi samrt band",  "moov now",  "moov hr",  "apple watch",  "fossil gen",  
                  "fossil sport smartwatch",  "fossil hybrid smartwatch hr",  "misfit vap, ",  "misfit ray",  
                  "misfit path",  "misfit command",  "withings steel",  "withings move",  "withings pulds",  
                  "withings move ecg",  "ihealth watch",  "samsung gear",  "samsung galaxy watch active",  
                  "samsung galaxy fit",  "polar a360",  "polar a370",  "polar m430",  "polar m200",  "polar h10",  
                  "polar vantage",  "polar ignite",  "polar grit x",  "polar titan",  "polar oh1",  "polar h9",  
                  "striiv fusion",  "striiv apex hr",  "striiv dash hr",  "huawei talkband",  " huawei watch",  
                  "huawei band",  "mykronoz zewatch",  "mykronoz zefit",  "mykronoz zesport",  "mykronoz zetime",  
                  "mykronoz zefit",  "mykronoz zeround",  "mykronoz zeneo",  "mykronoz zetrack",  "coros apex",  
                  "wyze band",  "letsfit fitness racker",  "coros pace",  "withings scanwatch",  "amazon halo",  
                  "timex ironman",  "suunto peak",  "wahoo fitness", "fitbit", "garmin", "apple", "xiaomi", "moov",
                  "fossil", "misfit", "withings", "ihealth", "samsung", "polar", "striiv", "huawei", "mykronoz", 
                  "coros", "wyze", "letsfit", "amazon"]

        resultwords  = [word for word in reviews[i].split() if word.lower() not in brands]
        reviews[i] = ' '.join(resultwords)


        #Remove category-related words
        categories = ["watch", "watches", "smart watch", "smartwatch", "band", "bands", "smartband", 
                      "smart band", "smartbands", "smart bands", "case", "cases", "cover", "protective", 
                      "protector", "screen", "show", "iphone", "express", "appleevent", "shield", 
                      "show", "appltv", "gear vr", "tv", "shoe", "mountain", "mountains", "beach", 
                      "appltv", "accessory", "accessories"]

        resultwords  = [word for word in reviews[i].split() if word.lower() not in categories]
        reviews[i] = ' '.join(resultwords)


        #Remove feature-related words
        features = ["ability", "quality", "feature", "aspect", "abilities", "qualities", "features", "aspects"]
        resultwords  = [word for word in reviews[i].split() if word.lower() not in features]
        reviews[i] = ' '.join(resultwords)

    return docs

# %%
reviews = np.array(df['Full Text'])
processed_reviews = clean_text(reviews)

# %%
processed_reviews
# Out:
# array(['nephew fact that waterproof finding black deal',
#        'series amazing but that health what attention',
#        'gem durability and battery life day hunt',
#        'stopped charging and bummed buy but glad that faster and clear',
#        'super work great for price highly recommend',
#        'excellent for space gray and great leaves access that switch easily',
#        'great that', 'and husband airy wear when working garden lot',
#        'love everyday learn but for lot money',
#        'item perfect imagine spending for true love love love big game changer',
#        'bought for relative series love and enjoying and learning bought',
#        'sport and bought and fell and broke bought and brand',
#        'forerunner heart rate monitor running black excellent convenient heath wellness',
#        'great affordable attractive',
#        'love stylish and for cant heart rate and burning',
#        'price though previous generation', 'and large display menu color',
#        'salesman patient friendly and knowledgeable what love buy',
#        'love easy wear and closure stays tightly closed bought for series and perfectly',
#        'capacity and longer cord than regular charger bit length love',
#        'love color addition now wear for day and and recharge',
#        'series and match perfectly and face sharp',
#        'comfortable ordered miscellaneous but',
#        'charge charge returned charge because uncomfortable wear',
#        'once before broke track sleep didnt even work for keeping track junk',
#        'wont charge phone pro charge series edition but wont work phone disappointed',
#        'charger that doesnt work fit rubber sleeve and charge completely purpose purchase',
#        'love charge but now connection broke glued plastic piece and tape',
#        'but hey android pretty fair purchase product work dont recommend honestly',
#        'received charger worth time return bought and hope kind bummer',
#        'bumper protect but difficulty',
#        'nice fit series stay locked loose returned',
#        'bumper for scratch while work perfectly', 'stuff but',
#        'market that cant stretch great life mate',
#        'hard connect charge phone even though list that compatible days',
#        'faded bad that for luck',
#        'ended because connect than that worked great',
#        'nice charge but after month start lift reseal but eventually start lifting',
#        'idea that convenient house worry phone room room',
#        'love smart display but battery bit longer coming lite',
#        'love accurate shower personally dont but who when highly recommend',
#        'browser support video fan for air fan', 'good and works issue',
#        'charge but now advanced charge place trick for',
#        'love cant imagine living and everyday finding awesome wearable',
#        'before but series and lot responsive',
#        'works happy that now when phone',
#        'easy attach secure wrist comfortable easy attach easily',
#        'gen nice accurate but good nicely built and worth price',
#        'bad works perfectly fine for but save money setup love',
#        'bought gift for birthday that price range battery life wife',
#        'love and but pay oxygen level',
#        'love track when walk face liking easy',
#        'quick easy order process and sell price easy and',
#        'excellent gift love paired phone and now read news track exercise routine diet',
#        'that easy metal easier and',
#        'cool device size perfect size that small', 'love pink and dirty',
#        'amazing love and than buy',
#        'love that buy buy for price for and doubt difference',
#        'for wife and comfortable and size charge',
#        'great and bought for wife and works great for suppose battery life good',
#        'and love product pretty and barely now',
#        'ordered and ready hour associate brought car love fitness',
#        'and perfect and cute buy for', 'happy purchase and generation',
#        'excellent product type when series easy clean soap and water',
#        'love easy light cooler for summer bought when open box',
#        'live bought and stays connected phone',
#        'gift timely because person who received check life saver',
#        'smart but and love fantastic huge beautiful and',
#        'love inspire and moving and making great progress helping lose great price',
#        'finally than and durable',
#        'which dont phone people house where convenient',
#        'and while happy league stylish comfortable and versatile',
#        'while love feel size bit smaller size and save difference price',
#        'love smart simple but and totally worth price',
#        'time perfect condition recommend watching tube comfortable setting',
#        'easy and pair phone fraction price purpose',
#        'than thought color photo great silver defiantly buy',
#        'for son daily and',
#        'and extra charger works perfectly recommend extra and save money',
#        'series excellent condition while update but update night speaker amazing',
#        'love but money and cool excellent fitness tracker gym',
#        'amazing for than and good device upgrade series',
#        'series love difference functionality though',
#        'love than love service received buy and for for',
#        'prestigious recommend strenuous adventurer and',
#        'nice graphics great clear and sharp picture',
#        'love fast delivery and love for fitness and handy for reading while working',
#        'black for wife birthday and rose gold belt good rose gold belt',
#        'rubber that doesnt wrist break and nice and tight',
#        'for easy and comfortable wear prefer plastic that standard',
#        'perfect stand for mode magnet links charger ease note additional charger',
#        'buy series and but glad',
#        'and that model point friendly and great buy',
#        'and for exercise time weather and talking phone', 'for and wear',
#        'morning morning loving wrist great',
#        'series cellular space gray aluminum sport space gray aluminum excellent',
#        'for perfectly plan trade highly recommend',
#        'love series enjoy and talk speaker microphone send text',
#        'and galaxy active even',
#        'long time and finally unending absolutely love',
#        'tech experience that active and conveniency series',
#        'teenage daughter for version what and great',
#        'bought for wife early gift and and price',
#        'buy awesome strong and attractive lots',
#        'everyday exception for now works and super intuitive',
#        'cant long cant leave house and work life easy when work',
#        'love but simplicity amazing simple and understand',
#        'favorite staff friendly and helpful when',
#        'series that crack glad making affordable but good option',
#        'for heart and blue color',
#        'return item because wife for birthday for sort time',
#        'magnetic charging cable for works perfectly plug port vehicle and',
#        'pretty easy and perfectly shipped and happy purchase',
#        'absolutely love gold stunning blue strap and bought gold magnetic mesh for',
#        'bought adapt charging cable connect traditional cable wall charger works perfectly',
#        'love heart issue and love that check and heart rate wonderful',
#        'stopped working item hold charge replacement accomplished',
#        'buy lot and useless safe and buy good',
#        'pin attach broken and strap fat fit slot that insert',
#        'return wrong size for but love shop buy store',
#        'what great and affordable alternative style simple and sleek and good for price',
#        'good experience but than',
#        'body and removed star because dirty quick but resolved quick wash',
#        'great alternative brand insignia phone and works charger good price',
#        'works and phone easy connect and music for sleep time close',
#        'series cant spot but nice and youve highly recommend',
#        'replace that broke good price paying for that dont',
#        'great video and easy setup great peace mind when sending motion photo phone and',
#        'great love that turn water mode and wear while swimming longer battery life but comparable',
#        'bought product charge since didnt box works designed and price decent',
#        'love health track fitness than happier purchase',
#        'charge and sense love dont that sense tho',
#        'for wife wanting blue replacement for for while now and great shape good buy',
#        'love connect phone and and receive and pickup phone',
#        'skeptical series but glad lot great specs love',
#        'love worth extra money bought because expensive and love',
#        'for absolutely fitness compatible easy cheap for',
#        'sixth and continuously rotate sons finish beautiful',
#        'works good phone life lot easier pick phone morning text',
#        'husband doesnt wear wrist when inspire purchase fit and happy',
#        'protect great and piece mind worry but great',
#        'expect comfortable and easy set battery life great',
#        'tool wife heart rate and sleep great tool for communication',
#        'smart before and stays for future smart',
#        'works fully easy set display nice bedroom bright night',
#        'great fit downfall that heat and day',
#        'gorgeous formal and casual comfortable wear product',
#        'charge which key sell for',
#        'great works great and track walking and activity great purchase and highly recommend for activity',
#        'love series worried that spending money but immeasurable',
#        'husband happy what doesnt that and good alternative',
#        'tough phone charger connection but works great and love that throw charge',
#        'and great face covered but impede touch', 'switched brand',
#        'charger for when traveling works great and short cord tripping charging cord',
#        'received and love easy and user recommend',
#        'what wonderful idea but and good',
#        'for daughter wasnt expensive and pretty loving',
#        'great smart that shame fisher smart listen millennial',
#        'original finally stopped working bought and love and than',
#        'inspire easier for wear than bracelet style great for counting and keeping',
#        'doesnt and but and effective listening music pain',
#        'series awesome and that for amazing daily',
#        'bought for style satisfied battery doesnt',
#        'love accidentally washer and works after soaked convenient check and',
#        'series and decided upgrade series great upgrade and battery life opinion great',
#        'bought for daughter replace faster works great and what loving',
#        'neat for price battery life excellent text great product',
#        'for family and sleep analysis which day',
#        'than pay since nice ease attractive',
#        'great and love display nice glance raise wrist battery day',
#        'works great box series bigger millimeter face user friendly',
#        'and works awesome mac and love unlock',
#        'for fitness but amazing that',
#        'bought replace great for and heart rate ring doorbell',
#        'for days single charge battery life than which main reason switched',
#        'order than and love and order bought that great',
#        'enjoy and wear daily close great for generation',
#        'time wear for professional atmosphere people when price',
#        'after wrist breaking rash wearing original comfortable and reaction',
#        'love replace and faster battery life tho workout counting accurate',
#        'time but glad love easy set and now everyday',
#        'original for falling wonderful replacement reasonable price',
#        'dont lived life great for healthy dont regret buy',
#        'love and long standing even waterproof swim problem',
#        'cant leave house phone and cycle service buy excellent',
#        'love but times which cellular version that when ozone',
#        'didnt charge happy wear lot and doesnt long charge',
#        'saved when forgot before catching softball game',
#        'love convenient because pull phone purse straight phone',
#        'love day that dont wear handy for when text change music and',
#        'series and great choice fast series and that bigger display game changer',
#        'cannot nice for price even extra bar nicely highly recommend',
#        'perfectly super sleek and color comfortable wear day',
#        'for birthday absolutely works great battery life but deal breaker',
#        'love super practical device mind built wearing android operating',
#        'and and and', 'sooner and works seamlessly great product',
#        'wrong voice phone camera remote fitness tracker nice thought device',
#        'love play music and lots gear fit',
#        'picked for daughter for birthday worn but now track sleep',
#        'great wireless charging pad for multiple wont work for didnt for',
#        'love product problem charge series long time',
#        'love love love great series series love hand wash and heart oxygen',
#        'love operation and fit replace older and face',
#        'thought finally convenience life worth price',
#        'functional charger nice design bought now for priced recommend',
#        'great buy and convenient bought fitness track but ton cool',
#        'spare charger for works great and faster than originally regularly',
#        'instinct while learn but easy start great',
#        'wife for and but display',
#        'for wife for nice soft touch material and breathe',
#        'great price charge for great for fitness and plenty teacher',
#        'series charging cable charger daily built good',
#        'love easier than easier keeping track heart rate while spinning',
#        'inspire ordered stopped working after couple received and longer works',
#        'lots air and felt cheap worth spent removed after',
#        'series charge device',
#        'horrible charge but doesnt work phone but worth price highly disappointed',
#        'year after charge quit working and success work even after reset',
#        'buy account but that for days business',
#        'disappointed edge peeled and now dirt stick',
#        'son but arm itch recommend',
#        'works gen smart current cable and kick bucket',
#        'series economically cheap and latest series',
#        'great fit for spot that catching and but item great',
#        'that great great stiff but happy',
#        'love husband color ways product amazing price tag steep but what pay for',
#        'happy good love cellular for when walking nice music carrying phone',
#        'love lot than fit bit but worth price totally enjoy',
#        'catalyst and great product protect',
#        'than standard solid that and comfortable because',
#        'lost original charge small for great wear everyday',
#        'specially when work physically pull phone text',
#        'love and stay fit moment breathe and heart health dope',
#        'series silver aluminum white sport silver aluminum bought for daughter love',
#        'item bathroom love and that plug while charging phone and',
#        'love perfect love great price good fit for tech and user friendly',
#        'and whatnot but time and halo contender',
#        'before and love glad switched when decided upgrade',
#        'sharp simple clean design easy perfectly and wrist color gorgeous',
#        'gift fir wife and thought but that happen light and sleek',
#        'buy love series busy workout reminder and love happy that',
#        'excellent android though wont beat android phone for price option',
#        'love gift and recipient hard for great entry',
#        'love cant wrong and and for smart',
#        'convenient when driving easy answer and heart rate and daily',
#        'since love perfect for and happy',
#        'before partial day for work animal hospital and when',
#        'happy bigger and battery life great and',
#        'charge for now and that for love and style',
#        'love light cooler for summer when open box',
#        'series edition flawless music and carrying phone',
#        'series great luxury work life easier idea and learning day',
#        'cake highly when choosing and fit bit love sleekness and phone',
#        'stay connected expensive luxury that but time favor buy',
#        'what before ring nice when and feel and informed',
#        'glad buy bigger sale than time works great recommend',
#        'love initially but fit bit saved',
#        'that for that long pretty good',
#        'love wear and everyday and quick lot great and specs',
#        'ionic but stopped charging after warranty and liking',
#        'great but longer offering which strange',
#        'love easier than previous charge clock enjoying',
#        'paired easily works great cute bumper for protect investment',
#        'since buy adapter for easy buy since wasnt included',
#        'great latest technology ease and data fabulous highly recommend',
#        'bigger good battery before but',
#        'amazing because change display time and heartbeat',
#        'that good price for purchase but',
#        'husband expensive because job and perfect for',
#        'wanting for awhile but love purchase sleek and easy',
#        'love for high and color fade good nut for price',
#        'love product that and cant imagine now when',
#        'works compliment charger series power adapter',
#        'bought record and and great job love',
#        'super amazing wanting track and long spending affordable and reliable great purchase',
#        'bought for mother who fancy for track great product',
#        'comfortable and ventilation great for exercise highly recommend for',
#        'bought for sons birthday didnt bought buy',
#        'bought fit ear since wear hearing works great work sound fantastic',
#        'love perfect for what for which running calorie counting when phone',
#        'bought series silver aluminum white sport silver aluminum product and performance awesome',
#        'but job and fancy', 'and felt upgrade hearing alert for great',
#        'daughter for family and service cant wrong',
#        'for long time gift love negative charge nightly',
#        'protect that expensive works good and face when place',
#        'good basic series extra functionality series great price point and sale that',
#        'original difference loving fast charge death fully',
#        'series for and that bought for year dad for birthday loving',
#        'love push and helpful dont phone sitting desk',
#        'face for that continually replace even', 'for for but when',
#        'love battery life great and days charging sleep and',
#        'charge good additional happy purchase',
#        'for while but hesitant wouldnt bulk small great and love',
#        'good for good price and decent scratches and set for',
#        'series stainless steel nice since stainless steel',
#        'hand since series continue purchase love for busy and',
#        'and loving drive lot and navigation notified turns and location dont',
#        'awesome staff informative purchase love easy maneuver and understand',
#        'loving didnt and expensive now what pay for and',
#        'easy install strap hold wear play basketball and undone easy remove and wash',
#        'wife everyday but exercise and and',
#        'great charger connected anker travel stand change phone pro and simultaneously',
#        'decided buy after health scare heart rate monitor and built monitor health',
#        'adapter for charger connect cable older power charger block item job',
#        'family love sleek and functionality for spouse for birthday',
#        'love and sport black sports enjoy screening cell phone neat and face',
#        'wanting for time and finally bit bullet amazing completely satisfied purchase',
#        'received which original beware electronics for',
#        'sport duo for dont bother worth money great for couple falling',
#        'product worthless glass stay and rubber bumper issue even worse',
#        'ironman that worked completely die box',
#        'returned and bought happier subscribe monthly didnt that idea',
#        'waste money returned couple days reach told',
#        'batter doesnt days',
#        'good product but trouble product for time couple small that',
#        'learning havent since gen love oxygen and heart rate battery life',
#        'silicone for broke after year and multiple adjustment',
#        'works but for buck for and wore and',
#        'good month buy associate install series and worked',
#        'love charge happy program insurance love that built',
#        'working fine whatsoever easy and rarely actual restart viper button',
#        'for fraction money missing written but figure',
#        'goodness naked and cant live device wrist',
#        'sharp simple clean design charge perfectly and wrist stylish and love color',
#        'bought for birthday and everyday fitness fitness',
#        'love series even user friendly than before fall bang',
#        'smart that android but compare display',
#        'device perfectly wahoo fitness phone and construction update review after',
#        'small wrist and perfectly love carbon fiber pretty nice and bulky',
#        'sport breathable than standard sport wrist doesnt feel sweaty',
#        'smart love and active activity program',
#        'works great than charger but stable night stand charge fast',
#        'amazing for perfectly for ventilation',
#        'love everyday track check and sleep night check sleep',
#        'loving upgrade charge that stopped working after crossing',
#        'because market now great and',
#        'for while and and decided process simple and happier',
#        'simple box feel phone properly even',
#        'big fan love option wrist nicely and enjoy compass series',
#        'love order and disappointed long but good price and buy good job',
#        'charger works and quick great when purse small bag',
#        'perfect lightweight dont even and easier',
#        'happy charge step charge glad dont constantly shower',
#        'prefer series for battery life didnt and form factor series',
#        'now learning time and and',
#        'nice upgrade that option face plate choose',
#        'love integration wireless charging and charging capability slot charge item',
#        'buy but glad bought colors great and easy durable than thought',
#        'class series excellent market highly recommend market',
#        'love works handy recall when hurry lot when phone',
#        'upgrade great smooth and sailing since bought hooked and process',
#        'works great tough hook but once easy and accurate lot than',
#        'love and learning happy',
#        'helpful than battery longer making day keeping charger handy boost',
#        'long while food turns perfect time and easy phone',
#        'bought for son gift and after year convinced purchase',
#        'but and exercise regimen that feedback performance filled void',
#        'real that real great when design and awesome',
#        'nice strong leather beautiful perfect for highly recommend product job',
#        'wasnt but realize dont carry phone time',
#        'excellent fitness main factor because track and walk day',
#        'ordered color variety charge and great easy and and nice colors',
#        'clutter and that fall night stand and nice view night for clock awesome product',
#        'stylish everyday and trick leave wrist sweaty traditional',
#        'great while recommend that buy replacement',
#        'preferred coverage bumper glass than separate bumper and glass protect face',
#        'charger works great that white scratch good buy for good product',
#        'upgrade series bit expensive',
#        'even though series works great and purpose for which extremely happy item',
#        'replace gear which love and upgrade',
#        'for option and function needing phone connected',
#        'bought series silver aluminum white sport silver product and performance awesome',
#        'daughter for family and service wrong',
#        'inspire great tool that honest and active while great cat face',
#        'love than love display after day',
#        'awesome product works for fraction price for year battery life great',
#        'love generation before but love workout',
#        'hard that while learn ordered for',
#        'happy purchase buy price buy', 'for battery life sleep',
#        'form gift for personal anniversary love extra and phone',
#        'for protect soft and good job that clear color',
#        'previous original major upgrade great battery life and',
#        'that fitted budget for long time finally and happier',
#        'for wife and daily battery life comfort and ease',
#        'love series easy and lot that enjoy experience great',
#        'told gift now owner and set for personal',
#        'sleep good and when battery doesnt days but enjoying',
#        'regular user for type work access text phone',
#        'love charger for turning when forgotten fully charge morning',
#        'enhance that magnetic and easy buy product color',
#        'love buckle easier and secure price opinion but for',
#        'generation and now picked because didnt health',
#        'and charge once week accurate and amazing',
#        'love inspire wrist small and slender time and description',
#        'beautiful for great material and great white and feel',
#        'charge before version exercise sleep heart rate and',
#        'high build that for infinitely adjustable fit works for and nice instantly',
#        'great for what flash while podium', 'love and',
#        'aware that special charging brick grateful when representative told that and',
#        'love for awhile and finally decided easy set and than',
#        'bought alternative work when received and turned after charging night',
#        'bought for and plastic that for',
#        'coating chipped day device poor appearance',
#        'easily after bought ionic absolutely and horrendous phone support',
#        'good but heavy and snaps hair waterproof that',
#        'good tracker but extra and good device for than',
#        'work great didnt and dont completely but learning and enjoying',
#        'because easy and and nice tech material soft durable and playable',
#        'love time smaller than series bigger display what',
#        'good coverage and minor that visible charge responsive',
#        'walk breeze sound good cutting but hindrance good',
#        'active even and easier than previous gear pro which for and',
#        'that version time that for while', 'protect but ended reckless',
#        'senior knowing oxygen level and heat rate close',
#        'great product for active but overly active individual love connect and track activity and price than',
#        'love love love version daughter', 'purchase hope open battery',
#        'track health and lost lot weight awesome and highly recommend before but perfect',
#        'browser support video moving now walking treadmill morning week',
#        'extra charger for charge for car for traveling what and',
#        'fantastic because send text and and and',
#        'love that dime since gif for birthday extra for bigger',
#        'bought open box when received practically absolutely love accountable for and shape',
#        'fitness than generation fitness journey losing',
#        'good for reliable and job for that highly recommend',
#        'love received gift and ended for year son works great and nice',
#        'gift purchase for husband love price tag',
#        'game changer for phone charger bonus but charge flying night stand',
#        'for charge good fit easy apply and scratching hard and rough',
#        'perfect gift for wife happy product excellent buy fine perfect gift',
#        'house charger for phone',
#        'and loving easy great and love that fitness free for',
#        'excellent warm handle grip original coupling perfect color remains',
#        'charge heart rate active',
#        'that great condition because durable protect and great price',
#        'love phone and physical and work harder day',
#        'reason dont because but when working',
#        'worth buy simple beautiful and great for and',
#        'great comfortable and sporty bought sale good deal regular price expensive but what pay for',
#        'perfect material that stays cool and great sizing and than that',
#        'bought for birthday replace and easier read',
#        'after smart decided easy set and extra workout and health',
#        'love galaxy active seamlessly phone and working and phone breeze',
#        'protect sale and since good item',
#        'great size and superb battery life for that big but track and heart rate',
#        'son wanting finally perfect for pay extra for series works great',
#        'love upset reward for dont buy',
#        'received birthday gift wall charger buy charger store and purchase that day',
#        'decided stainless steel version glad love weight and feel series',
#        'touch for nice which son lot bright',
#        'original series and love love swim',
#        'since lite and after and love and change easily',
#        'and satisfied works but now problem wearing day',
#        'and feel great for easy stays and great warranty program',
#        'and perfect condition love for', 'and battery life',
#        'sport for brown and light blue killer orange picture dont justice',
#        'perfect for and for what works excellent wont complete easy install and setup',
#        'love battery life love who wrist love',
#        'than ape days and sturdy and high tech time great awesome purchase',
#        'bought for wife leather and great size',
#        'before and helpful easy and fitness',
#        'super cute people because and people',
#        'for birthday absolutely easy program battery life awesome highly recommend',
#        'and regular exercise schedule aware sleep hygiene',
#        'for easy that pristine shape',
#        'perfect condition and works perfectly fine loving and nice faster than thought',
#        'happy purchase price buy', 'wore for though for change while',
#        'bought ionic for husband for day and upgrade previous',
#        'and hesitant update price once open product price bought',
#        'for and for that didnt perfect',
#        'love price simple bought and stretch',
#        'version for great price but and color great',
#        'who when comfortable accurate and easy stays for week',
#        'worked beautifully and saved charge happy product and fit perfect for saving time and money',
#        'works and wireless charging small and light and and small love',
#        'good times and highly recommend wearer',
#        'product because charge phone and phone phone while',
#        'love fast easy battery life long charge once day',
#        'beating absolute purchase and for price cant wrong',
#        'love than charge doesnt long bur charge before leave house morning',
#        'charge charge and now love bought',
#        'color but rose color but that shiny sliver color and love',
#        'simple and sophisticated comfortable for who sophisticated',
#        'great for nice and save lot money highly recommend',
#        'good cheap good but super cheap and battery for days and',
#        'multiple smart and but track health and sleep',
#        'previous happy love that dont phone nearby for',
#        'favorite sport color aquamarine blue than green for which than usual',
#        'chose works phone and send text listen music',
#        'love and stainless steel mesh enjoy screening cell phone neat and face',
#        'husband for super light weight easy clean which great since works outdoors',
#        'easy install shorten and easy shorten beautiful rose gold color',
#        'but easy after year and longer warranty smart durable',
#        'when and cost absolutely useless product',
#        'bought because charger working portion holder for charger product',
#        'inspire lunar white good hard set son but return set',
#        'horrible cheap knock buy data secure and read',
#        'nice party play store switched and comparison',
#        'great for price but returned for cellular but for what kind than',
#        'previous series and satisfied love display busy',
#        'love inspire wasnt sleep but helpful mobile easy and convenient',
#        'skeptical but now wondering procrastinating',
#        'highly recommend buy upgrade display nice and battery long lasting',
#        'awesome but medical that easy and blue cool',
#        'series cellular cellular connect family while and',
#        'absolutely love buy pick perfect for patient',
#        'awesome purchase sale great purchase and easy buy',
#        'great and for mix wine metal mesh and silicone',
#        'speak for battery good and works fine',
#        'long time series bit worth money love awesome',
#        'great comfortable approach than that',
#        'thinking series but and and understood but now',
#        'husband than charge longer and nice',
#        'switched galaxy and dont regret for awesome battery life amazing and love',
#        'sharp simple clean design easy perfectly and color gorgeous',
#        'and cant showing amazing piece technology and great battery life',
#        'that waterproof and opportunity while swimming',
#        'great love text and phone leaving stay free',
#        'love phone and return bulky and great',
#        'awesome product received gift thought that received now live',
#        'strong strap felt durable and easily cleanable because which lite broke set strap good for money',
#        'recommend for price and functionality interface easy and which',
#        'works fully set nice bedroom bright night',
#        'genuine leather strap for excellent price series perfectly pink color gold color',
#        'love product for couple and enjoy works great for and physical activity',
#        'love that that light night and track sleep handy',
#        'super easy and feel that protect expensive collect bit dust but easily and wipe clean',
#        'charge easier set activity charge swipes set start activity and',
#        'super easy and love avid runner and than',
#        'great coming huge upgrade and love display fantastic and easy setup works phone',
#        'product time great shape and what organized and provide area charge phone and',
#        'great product works sleep water and food check weather and receive text',
#        'perfect upgrade series and decided treat dont regret purchase love',
#        'great fit perfectly and but fraction cost highly recommend',
#        'original charger for broke bought replace and worked great great price',
#        'debating for and glad plan son and version',
#        'absolutely love for now and super convenient and love fitness option',
#        'wow great barely but when sale jump exquisite',
#        'happy for battery life functionality',
#        'than that charge feel that longer than that charge',
#        'love big that worth price and',
#        'that times year jump and happy highly recommend',
#        'upgrade for archaic that previous generation higher',
#        'athlete outdoor adventurer general sports fitness enthusiast great',
#        'that replacement for charge color vibrant easy and wash clean',
#        'bought for heart and movement love',
#        'favorite battery life infinitely longer than comfortable and easy',
#        'bumper gold and saved than scratches accident prone highly recommend',
#        'love birthday wear everyday day love',
#        'work and time reply message phone handy reply',
#        'good for product and that what',
#        'nice inexpensive charger worked for wife pinch when forgot charger after heading town pickup great',
#        'gifted wife for and ecstatic when highly than',
#        'user friendly basic light weight and easy bind phone and love heavy and',
#        'series excellent heart rating breathing and time stand',
#        'double mouse pad banging edge than for price',
#        'good bumper style for dirty work and while replace',
#        'blaze day battery life which picked for clock and',
#        'hubby easy battery charge day for',
#        'love comfortable wear great easy clean and wrist highly recommend',
#        'thought buy but price for time and and now track activity and ensure stay healthy',
#        'long time and finally unending absolutely love',
#        'good product for deaf people when that when signal',
#        'love glad bought phone who calling and respond text',
#        'love heart monitor and peace mind medium wrist and perfect',
#        'upgrade daughter communicate phone but didnt huge price tag perfect option',
#        'love headset big upgrade gear advice for buy halo headset provide uncomfortable',
#        'modal silicone for blue daughter durable water bought colors',
#        'lost didnt buy',
#        'great helpful when work and when breathe when road drive manual car',
#        'purchase and happy price and service received knowledgeable and friendly',
#        'bought for wife dresser for fit feel and appearance purchase',
#        'good for wife works for recommend friend',
#        'charge since summer for and absolutely tracker',
#        'happy inspire what slim and sleek battery charge for long time today',
#        'works great for quick charge super bright which nice cable charger and worked',
#        'love young lady who outstanding job knew product and even priced',
#        'charge replace nice but when fall',
#        'long overdue for refresh series ultra and change love design and',
#        'great battery life days solid charge size big but feel big wrist',
#        'sense charge and love even moving and',
#        'replace week and happy for daily',
#        'absolutely love and super comfy and glad chose',
#        'work for even though description black edge which display',
#        'work for plastic sticky and easy which drawing board',
#        'longer works dead after normal bought for birthday unfortunate mistake purchase',
#        'that good work for but slow and for returned and',
#        'mood doesnt work wrist hurt wear long lack feedback device hard track progress',
#        'product time bought gift for daughter who didnt but mommy',
#        'bought replace and great for and accurate lack annoying',
#        'great rose gold downside that material that breathable sweat',
#        'love series smooth and flawlessly series what meant',
#        'item for and nice that expensive but expensive',
#        'easy fan but absolutely love special when work dont carry phone',
#        'good color awesome disappointed that area colors washed and brilliant',
#        'wasnt long for wrist and responsive version big upgrade charge',
#        'love galaxy switch and times stuck outdated ways paying outrageous for limited',
#        'and issue that cannot resolve face',
#        'love track physical activity and love that when text message coming',
#        'easily and doesnt interfere cheap but sturdy and peace mind knowing',
#        'charge love and wearing now love flexibility',
#        'inspire fitness tracker black great birthday gift easy good recommend',
#        'good for series and worried scratches while naked',
#        'love and that for year glad finally',
#        'great power strip for when traveling than for phone tablet speaker and',
#        'great deal stainless model high product and upgrade improvement battery life day for',
#        'daughter and favorite color mint green good price and perfect fit for series',
#        'love series series but good series bought brand great price',
#        'for wife wanting blue replacement for for while now and great shape good buy',
#        'bad works perfectly fine for but save money easy setup love',
#        'for and absolutely love battery life good and charging for',
#        'for clean and smooth fake and plastic turn yellow',
#        'set that hooked phone person busy good service',
#        'daughter perfect for active love bouldering rock climbing and color for',
#        'expect comfortable and easy set battery life great',
#        'love ready latest version when funds recommend for who health and',
#        'love choice purchase buy than store',
#        'gifted hubby for and light that notice wearing',
#        'permanent fixture easy and attached gen',
#        'great and water and scratches year great',
#        'great for perfectly and sense peace that phone surface',
#        'unsurpassed and tech great buy',
#        'for stand charge and idea that time while charging',
#        'tough phone charger connection but works great and love that throw charge',
#        'pretty what lot but',
#        'thought since everyday and feel lost glad finally decided purchase',
#        'easy set and stylish niece',
#        'that ionic torn replacement item perfect for that color',
#        'great and good for series snappy and works great',
#        'series daughter and when version for birthday',
#        'love love great and love and recommend',
#        'bought health for now love wear single day but',
#        'love and calling but pretty dose dose',
#        'love change feeling love color and',
#        'love upgrade series love bigger but love that keyboard when text',
#        'love rocking since addition for amazing comfortable and stylish',
#        'series great buy easy and delay lag works great regret',
#        'love enjoying time and design purchase for teen for which love',
#        'waiting than watchless fit bit premium battery life sold',
#        'love works for phone reaching for phone set easy and nice',
#        'son bought for aunt and flag colors support good',
#        'year and and great everyday great purchase love bought',
#        'absolutely love since smart bit learning curve but feel pretty comfortable now',
#        'love sleek and convenience literally kind product buy',
#        'series works great love and daily battery longer than day for but love',
#        'love pro easy and love touch recognition and connection unlock great',
#        'for son and absolutely but ready for that awesome alternative',
#        'simple lot option company',
#        'approach and depend shot measuring pin actual location and scoring good',
#        'nice bike and peloton works great magnetic resistance but worth buy',
#        'for price hybrid leather worth nice and nice recommend',
#        'great video pack excellent great length highly recommend for mon item lots fun multiple times',
#        'excellent light weight and accurate reading husband and than',
#        'what for nice and easy links adjust wrist',
#        'love silver version series but broke black and clean finish',
#        'combination cell phone and stand sturdy and great for price highly recommend',
#        'for for health than phone and great start for long time',
#        'love series smooth and flawlessly series what meant',
#        'love for track step and recommend love',
#        'great workout tracker nice display satisfied purchase and glad saved extra',
#        'bought for son what work but great product',
#        'love beautifully built piece love that time lift arm',
#        'since series and series highly recommend for battery life greatly worth upgrade',
#        'series great love and text amazing glance love',
#        'comfortable great silver color beautiful and great great combination colors',
#        'happy charge comfortable wear wrist and display pretty tough item',
#        'for wife and works great and easy when product credit for mindfulness',
#        'magnetic charging cable bought extra office charge forget charge',
#        'for birthday absolutely works great battery life but deal breaker',
#        'perfect for easily and constantly cell phone',
#        'charge working now connected properly touchy works',
#        'cannot beat price mile what hour and charge week',
#        'bought and charge for wife decide which comfortable and for',
#        'great leather sturdy and durable than bought for',
#        'for family member who and greater versatility family member device',
#        'heavy duty and charge once everyday recommend',
#        'big upgrade for series loving smoothness when multiple lag color',
#        'absolutely love perfect small wrist satisfied purchase for what for long',
#        'works inexpensive solution for purchase expensive charging cube for',
#        'priced notification highly recommend product',
#        'replace year after for assuming real profit',
#        'bought for broke money guarantee but shipping and handling worth',
#        'clasp stay and day fell wrist and broke because stay',
#        'fit large click housing for buy waste time and money',
#        'since charge warranty good for days cannot support',
#        'good works great galaxy phone ease but for',
#        'great product love ionic even though recommend meet basic',
#        'nice works cant track and occasionally disconnect but purpose and',
#        'basically talk text happy purchase',
#        'wonderful job scratches and for that spent hard money',
#        'fine and fit charge perfectly after ring that rest broke',
#        'series and lightweight for price cant beat',
#        'series simple navigation tricky times but bought sale',
#        'ill start review dont buy promote exclusively phone happily android and dont',
#        'great but and for what love convenience and plan buy older version',
#        'that expensive but what pay for',
#        'catalyst and great product protect',
#        'love tortoise happy and feel extra pop',
#        'comfortable worn black and brown easily sync wardrobe',
#        'pretty straight which practically universal now built charging cable',
#        'absolutely love perfectly and what awesome buy for helping decide which for',
#        'absolutely love series that heart monitor love',
#        'specially when work physically pull phone text',
#        'winner replace model after original satisfactory respect',
#        'for for figured', 'for now that finally decision purchase',
#        'great product for and nice daughter for graduation gift happy',
#        'thought but once havent amazing and product',
#        'life wake and where phone when harder for unplug',
#        'absolutely bomb dot closure magnetic sons for',
#        'bought for active and now for series durable comfortable and stylish',
#        'bought wife track fitness resolution',
#        'platinum leather for inspire and inspire copper perfect for colors than standard',
#        'happy purchase good price sale exploring',
#        'great for price but that wasnt protecting bought days',
#        'amazing for that for daily life and work glove and doesnt disappoint for',
#        'cant wrong and amazing highly recommend running ease',
#        'fantastic and person who understand series series extremely helpful',
#        'real gold class tech device jewelry collection',
#        'buy buy and love adorable fit adjust that fit wrest',
#        'wife lot issue fall detection message even catch loose',
#        'perfect feel lightweight even and easier',
#        'good strap hard works what original strap but',
#        'great alternative for fitness calorie counting lose for counting lightweight and cute',
#        'for work since work medical field super easy and love and',
#        'for time and decided finally',
#        'worried wasnt compatible note but once fully paired fine and love',
#        'ionic but stopped charging after warranty and liking',
#        'long before great phone purse and',
#        'bought for heart and movement love nit',
#        'now and and honestly comparable though',
#        'wife couple and unit easy and fit for wife',
#        'smart before diet time purchase and glad and and loving',
#        'bought open box longer standard connection power which',
#        'good fit for for time user what ensure safety for',
#        'pretty but affordable envy super expensive that cost fortune easy manage lovable pink',
#        'preferential price smart for good for what',
#        'good product and health great battery life longer',
#        'love product that and imagine now when',
#        'works compliment charger series power adapter',
#        'lot charge but broke and bought works and data than',
#        'bought for husband who and mention now which easier share',
#        'comfortable and ventilation great for exercise highly recommend for',
#        'sturdy charger fit perfectly great for keeping and phone place where worth price',
#        'comfortable lost because that undone easily and',
#        'excellent replacement affordable and high cute color ordered for family that charge',
#        'for wife but returned for since designed work',
#        'buy pick after previous and tearing great love',
#        'test and worth price exercise than lighter than and battery life great',
#        'great stand and breathe design lot learn',
#        'love for charge quick easy apply detailed helpful affordable',
#        'after wife for than', 'series awesome hybrid face nice for',
#        'repair tech didnt absolutely product and cant wait coming',
#        'wife love since that fitness for',
#        'and purchase undoubtably smart market',
#        'love battery life multiple and battery life night',
#        'plug accompany gift because didnt included good works intended',
#        'product works bit time strap havent before but works great',
#        'love love love series life easier carry phone and when unable who',
#        'for and wore day and feel model nice',
#        'works charger that bulky but job and',
#        'love inspire fitness tracker easy and track and heart rate stay fit',
#        'love dont variety free for',
#        'super easy for pool and great for summer when wrist heat and humidity',
#        'wonderful monitor love that but phone works',
#        'before and love great product problem battery life but than that complaint',
#        'love check heart rate and check heart for fib awesome access check heart rhythm',
#        'love for moving and hit gym',
#        'for while but hesitant bulk small great and love',
#        'favorite charger car and charge stunning easy and word pro',
#        'works and stopped working great backup charger and expensive branded',
#        'great deal everyday personal trainer and helpful love track compete',
#        'oxygen meter accurate and heart rate reading accurate works for and',
#        'and love favorite and stand goal track fitness',
#        'charge working great for android accurate granite sweaty',
#        'replace after daily great replacement that',
#        'switched and switched because love review',
#        'love dont charge days days for workout and',
#        'decent bigger but product recommend since easy',
#        'series good for teens wanting sleek design performance great',
#        'worth penny lot battery long time track sleep nice',
#        'for bit decided mid price option love and highly recommend',
#        'great wireless charging solution for and phone single cable and transformer included high feel',
#        'enjoying lot than before learn',
#        'happy size for favorite love color and',
#        'sweet spot for and love great and battery day',
#        'easy and button and emergency number recommend item',
#        'waste money works for charge but charger port fit properly piece',
#        'return charge time charge phone time',
#        'return expect remember correctly cant people trust connection',
#        'great product for what functionality though and',
#        'hold phone support adjustable phone small wallet great',
#        'waiting purchase when sale convenient battery longer',
#        'fine great and didnt since fully good',
#        'love wireless charger for phone but gear phone sitting properly lose wireless charge',
#        'love but disappointed graphics for previous graphics which times',
#        'works pretty good problem that easy access for when water',
#        'and bigger nice battery life good but day',
#        'love track basic health blood majority what',
#        'dont pay send pretty good doctor but expensive',
#        'love track for day and heart rate pretty accurate and spot',
#        'after user but unnecessarily complex and',
#        'perfect gift for day literally wife arrive time and',
#        'smaller prefer smaller size because light wrist',
#        'pretty straight which practically universal now nicely built charging cable',
#        'great piece technology model when huge difference loving level for',
#        'enjoying tremendously that that daily days charge great',
#        'good great built red color beautiful metallic for red recommend',
#        'learn but chose than life alert',
#        'small sleek and accurate inspire love gemma mart small sleek and accurate review',
#        'for linked fit and sale price good',
#        'charge working while set though older set',
#        'for and thought size issue but awesome lots and tough',
#        'love size great fit perfect love that cant quick phone time',
#        'series because receive easy and record exercise routine',
#        'absolutely love series for keeping track totally addicted and wear everyday',
#        'great deal now selling which suppose good experience buy set broken',
#        'love than easier handle and lot opinion',
#        'love purchase and stay organized and active highly recommend',
#        'love series fitness and productive',
#        'brand series and for size worth price works flawlessly and sealed box',
#        'series and for battery',
#        'prefer original open box which knock soft and comfortable',
#        'big fan love option wrist nicely and enjoy compass series',
#        'bought for son that color blue and change color graduation',
#        'lot series and lot',
#        'wear day everyday quick charge once day absolutely and since',
#        'love love love ionic loyal customer for and device and honestly favorite',
#        'for husband because felt making phone wrist time partial disconnect',
#        'for birthday and and works brand wrong buy',
#        'love but what and battery life great highly recommend',
#        'super love since and didnt upgrade but',
#        'version love bigger and responsive series',
#        'works fantastic box easy and that reasonable price',
#        'cord perfect job efficiently and portable change bit longer',
#        'perfect bed table and easy bed huge but for phone and charge while sleep',
#        'nice strong leather beautiful perfect for highly recommend product job',
#        'series great for health and everyday life time',
#        'gear and pretty great sleep and layer',
#        'love for price cant beat husband paying for data plan good',
#        'lie super decided while working and working and handy',
#        'great addition ride and stays tight vibration and wind hesitate purchase',
#        'finally that sense charging station that charge phone and time convenient location',
#        'gift and love awesome than flex highly',
#        'and love love love big fan thinking disappointed',
#        'love small size classic squared sleep work and even heart rate pretty and good',
#        'blaze for switched glad disappointed',
#        'inspire and love wear time and dont worry wet highly recommend device',
#        'love works great air unlock cool that',
#        'lot missing couple but for price match connection easy and simple',
#        'love and discount buy for easy purchase and for tech',
#        'repair tech didnt absolutely product and cant wait coming',
#        'love when break since life chaotic nice reminder when break',
#        'purchase series and battery life extra charge since night',
#        'that buy excellent talk while work stopping work answer',
#        'for wanting since before that',
#        'high but device control mechanism large dial',
#        'replacement for lost charge charge that seek fitness monitor and great',
#        'love bought original working today love fantastic and great health',
#        'bought gift friend and enjoying everyday highly recommend product',
#        'enhance that magnetic and easy buy product color',
#        'super convenient for protecting table and wall times but damages glad purchase',
#        'perfect for for and even recommend',
#        'love bought because series broke and thought time for upgrade',
#        'pretty nice fitness stay but for',
#        'great stainless steel variance keeping for spend money and',
#        'clear bumper protect that clear that attractive color visible',
#        'love user friendly purchase and style honest',
#        'great tool for link size and tool and time',
#        'love bracelet comfortable and stylish recommend that style',
#        'huge upgrade stylish and works flawless which big',
#        'bought series for starter comfortable easy battery life issue recommend',
#        'when learn lesson year and charge month for good',
#        'clasp fell losing lucky location phone day long return wast money',
#        'considerably than charger short cable length nice but charger that',
#        'bought for wife and display beautiful and works for lot',
#        'bought sleep but now for day remember pretty comfortable',
#        'wife and son and love update tricky times but than that good',
#        'works protecting bump notice that chip bit but save breaking',
#        'perfectly charge size smaller lot extra',
#        'lose after purchase care leaving after weight gym',
#        'time and specially heart sensor lot track recommend',
#        'magnetic charging cable what meant and while nicely travel mount',
#        'good solid for bit clumsy magnet but sturdy and comfortable',
#        'for friend sale and great price and absolutely highly',
#        'bad and finally caught steal love and change great product',
#        'purchase hope open battery',
#        'track health and lost lot weight awesome and highly recommend before but perfect',
#        'highly recommend because size love recommend future buy',
#        'good complimentary for switch for',
#        'love compare but works perfect great for exercise',
#        'for daughter didnt because feminine happy',
#        'for younger and but fantastic for price',
#        'excellent sale for opportunity for buy purchase',
#        'love working and yard work enjoyable pair listen phone',
#        'love convenient for when phone and trade',
#        'switched series fantastic upgrade that worried knocking happy',
#        'great product plan open and close door good',
#        'reason because but when working',
#        'wasnt but now that love and than thought and day',
#        'love great phone pocket when working phone',
#        'love easy for paying for wallet ease and lot accessible wrist',
#        'love and older and working great',
#        'good wise even battery life longer charge night and wore day',
#        'display feel standard and battery life unbelievable',
#        'thought keeping task fitness time pandemic',
#        'light weight and accurate love accountability phone and free now',
#        'bought spare charger since battery charger works great and battery',
#        'series and recommend',
#        'great series great battery life day and day buy quick fast and reliable',
#        'glasses great eye strain and sleep tracked charge recommend',
#        'favorite phone perfect for work because',
#        'great device everyday battery life amazing than store music which great',
#        'functionality glad didnt pay for model because',
#        'smart for while now and series bigger and rounded awesome',
#        'nice lots recommend product battery life good when charge remain for days',
#        'strong nicely charge didnt and',
#        'great and days and battery life basic comparable',
#        'worn daily ionic dont and lot than for device',
#        'charging cable for that bought works and price good buy and recommend',
#        'and and for long',
#        'and view and send performance price cheap for',
#        'live even whoop tracker love connected when phone',
#        'time hubby bought after when finally split',
#        'great and great price for great highly recommend buy',
#        'received day gift perfect compact device charge phone and fast charging and works',
#        'lite great stay healthy price sleep monitor great',
#        'gift for comfortable wear happy',
#        'partner wanting and cant group',
#        'love generation faster phone great worth money',
#        'health fantastic worse than galaxy active enjoy',
#        'wear time charge and classy and fun comfortable and easy links fit wrist',
#        'because simple and quick long and unlock good',
#        'daughter excited and now reaching exercise and stand win win for',
#        'than bit long compatible charger works series fast',
#        'great smart love and ease view concern scratching cracking',
#        'love disadvantage for couple and now battery long before',
#        'big upgrade series and lot cool that series didnt and battery life',
#        'bar for fitness and style leave motivate active and godsend',
#        'love upgrade fir birthday series and figured time upgrade love',
#        'what and great product and great afraid hurt great replacement for',
#        'daughter for and love daughter and happy papa smile',
#        'love long charge days dislike dress and nice dress',
#        'and husband wear when working garden lot',
#        'love charge charge suddenly stopped working and matter what wouldnt work glad bought charge',
#        'expect smart phone level but android',
#        'wife and surprise charging adapter works perfectly but damn shame that buy',
#        'small size charge short time but working nice easy adjustment fit easy change',
#        'series series love display that series',
#        'original cable and wouldnt charge properly stand thickness ring doesnt charge properly',
#        'stay charge times day and store defective box',
#        'and but doesnt fit after professional',
#        'once inspire than battery which week now rendering pretty useless',
#        'ill love series ass geet',
#        'love complaint battery day open recommend',
#        'shipped paper unbelievable damage good job update works fine thankfully',
#        'face real game changer that than previous version',
#        'pretty good easy clean mild soap and water perfectly happy purchase and recommend',
#        'nice design good magnet strong fall kind expensive but good',
#        'good protect that hard but easier once cleaning',
#        'visiting figure manual reference',
#        'wife and travel wont long loose charger replacement affordable and works',
#        'nice for price bought for wife since handed daughter works',
#        'easily but when caught plastic and protect nicely',
#        'works fine for charging disappointment purchase separately included',
#        'perfect addition sense and easy and active and ecosystem reason',
#        'bought love great lighting love charge phone and night stand nicely built',
#        'series met that fitness target exercise incoming phone',
#        'work long and phone text and and soother cool',
#        'and version slim and and big and bulky whatsoever',
#        'since time what expect great dont havent bought sooner',
#        'replacement for charge buy replacement order and pay additional shipping',
#        'for day but love that doesnt feel bulky wrist feel',
#        'great and and longer than',
#        'love ionic because and expensive but worked good',
#        'great love color buy expensive than store buy',
#        'bigger face and dictation than great product',
#        'upgrade previous disappoint that waterproof for but functional for',
#        'series amazing super fast bright crisp and clear oxygen sensor works great super easy set and great product',
#        'disappoint and process buy quick and easy',
#        'love phone and return bulky and great',
#        'perfect fit easy install durable comparable but affordable glad purchase recommend',
#        'sport loop for and favorite style lightweight comfortable sweatproof adjustable for perfect fit',
#        'interact day long returned upgrade series because worth investment',
#        'finally works great ways neighborhood everyday'], dtype=object)

# %%
d = ['& ', ', ','; ','! ',': ','for ','and ', 'but ', 'or ', 'so ',
     'after ', 'as ', 'because ', 'before ', 'even ', 'if ', 'now ', 'once ', 
     'since ', 'than ', 'that ', 'thought ', 'when ', 'where ', 'which ', 
     'while ', 'who ', 'what ']

for i in range(len(processed_reviews)):
    processed_reviews[i] = split_string(processed_reviews[i], d)

processed_reviews
# Out:
# array([list(['nephew fact ', 'waterproof finding black deal']),
#        list(['series amazing ', '', 'health ', 'attention']),
#        list(['gem durability ', 'battery life day hunt']),
#        list(['stopped charging ', 'bummed buy ', 'glad ', 'faster ', 'clear']),
#        list(['super work great ', 'price highly recommend']),
#        list(['excellent ', 'space gray ', 'great leaves access ', 'switch easily']),
#        list(['great that']),
#        list(['', 'husb', 'airy wear ', 'working garden lot']),
#        list(['love everyday learn ', '', 'lot money']),
#        list(['item perfect imagine spending ', 'true love love love big game changer']),
#        list(['bought ', 'relative series love ', 'enjoying ', 'learning bought']),
#        list(['sport ', 'bought ', 'fell ', 'broke bought ', 'brand']),
#        list(['forerunner heart rate monit', 'running black excellent convenient heath wellness']),
#        list(['great affordable attractive']),
#        list(['love stylish ', '', 'cant heart rate ', 'burning']),
#        list(['price though previous generation']),
#        list(['', 'large display menu color']),
#        list(['salesman patient friendly ', 'knowledgeable ', 'love buy']),
#        list(['love easy wear ', 'closure stays tightly closed bought ', 'series ', 'perfectly']),
#        list(['capacity ', 'longer cord ', 'regular charger bit length love']),
#        list(['love col', 'addition ', 'wear ', 'day ', '', 'recharge']),
#        list(['series ', 'match perfectly ', 'face sharp']),
#        list(['comfortable ordered miscellaneous but']),
#        list(['charge charge returned charge ', 'uncomfortable wear']),
#        list(['', '', 'broke track sleep didnt ', 'work ', 'keeping track junk']),
#        list(['wont charge phone pro charge series edition ', 'wont work phone disappointed']),
#        list(['charger ', 'doesnt work fit rubber sleeve ', 'charge completely purpose purchase']),
#        list(['love charge ', '', 'connection broke glued plastic piece ', 'tape']),
#        list(['', 'hey android pretty fair purchase product work dont recommend honestly']),
#        list(['received charger worth time return bought ', 'hope kind bummer']),
#        list(['bumper protect ', 'difficulty']),
#        list(['nice fit series stay locked loose returned']),
#        list(['bumper ', 'scratch ', 'work perfectly']),
#        list(['stuff but']),
#        list(['market ', 'cant stretch great life mate']),
#        list(['hard connect charge phone ', 'though list ', 'compatible days']),
#        list(['faded bad ', '', 'luck']),
#        list(['ended ', 'connect ', '', 'worked great']),
#        list(['nice charge ', '', 'month start lift reseal ', 'eventually start lifting']),
#        list(['idea ', 'convenient house worry phone room room']),
#        list(['love smart display ', 'battery bit longer coming lite']),
#        list(['love accurate shower personally dont ', '', '', 'highly recommend']),
#        list(['browser support video fan ', 'air fan']),
#        list(['good ', 'works issue']),
#        list(['charge ', '', 'advanced charge place trick for']),
#        list(['love cant imagine living ', 'everyday finding awesome wearable']),
#        list(['', '', 'series ', 'lot responsive']),
#        list(['works happy ', '', '', 'phone']),
#        list(['easy attach secure wrist comfortable easy attach easily']),
#        list(['gen nice accurate ', 'good nicely built ', 'worth price']),
#        list(['bad works perfectly fine ', '', 'save money setup love']),
#        list(['bought gift ', 'birthday ', 'price range battery life wife']),
#        list(['love ', '', 'pay oxygen level']),
#        list(['love track ', 'walk face liking easy']),
#        list(['quick easy order process ', 'sell price easy and']),
#        list(['excellent gift love paired phone ', '', 'read news track exercise routine diet']),
#        list(['', 'easy metal easier and']),
#        list(['cool device size perfect size ', 'small']),
#        list(['love pink ', 'dirty']), list(['amazing love ', '', 'buy']),
#        list(['love ', 'buy buy ', 'price ', '', 'doubt difference']),
#        list(['', 'wife ', 'comfortable ', 'size charge']),
#        list(['great ', 'bought ', 'wife ', 'works great ', 'suppose battery life good']),
#        list(['', 'love product pretty ', 'barely now']),
#        list(['ordered ', 'ready hour associate brought car love fitness']),
#        list(['', 'perfect ', 'cute buy for']),
#        list(['happy purchase ', 'generation']),
#        list(['excellent product type ', 'series easy clean soap ', 'water']),
#        list(['love easy light cooler ', 'summer bought ', 'open box']),
#        list(['live bought ', 'stays connected phone']),
#        list(['gift timely ', 'person ', 'received check life saver']),
#        list(['smart ', '', 'love fantastic huge beautiful and']),
#        list(['love inspire ', 'moving ', 'making great progress helping lose great price']),
#        list(['finally ', '', 'durable']),
#        list(['', 'dont phone people house ', 'convenient']),
#        list(['', '', 'happy league stylish comfortable ', 'versatile']),
#        list(['', 'love feel size bit smaller size ', 'save difference price']),
#        list(['love smart simple ', '', 'totally worth price']),
#        list(['time perfect condition recommend watching tube comfortable setting']),
#        list(['easy ', 'pair phone fraction price purpose']),
#        list(['', '', 'col', 'photo great silver defiantly buy']),
#        list(['', 'son daily and']),
#        list(['', 'extra charger works perfectly recommend extra ', 'save money']),
#        list(['series excellent condition ', 'update ', 'update night speaker amazing']),
#        list(['love ', 'money ', 'cool excellent fitness tracker gym']),
#        list(['amazing ', '', '', 'good device upgrade series']),
#        list(['series love difference functionality though']),
#        list(['love ', 'love service received buy ', '', 'for']),
#        list(['prestigious recommend strenuous adventurer and']),
#        list(['nice graphics great clear ', 'sharp picture']),
#        list(['love fast delivery ', 'love ', 'fitness ', 'handy ', 'reading ', 'working']),
#        list(['black ', 'wife birthday ', 'rose gold belt good rose gold belt']),
#        list(['rubber ', 'doesnt wrist break ', 'nice ', 'tight']),
#        list(['', 'easy ', 'comfortable wear prefer plastic ', 'standard']),
#        list(['perfect st', '', 'mode magnet links charger ease note additional charger']),
#        list(['buy series ', '', 'glad']),
#        list(['', '', 'model point friendly ', 'great buy']),
#        list(['', '', 'exercise time weather ', 'talking phone']),
#        list(['', '', 'wear']),
#        list(['morning morning loving wrist great']),
#        list(['series cellular space gray aluminum sport space gray aluminum excellent']),
#        list(['', 'perfectly plan trade highly recommend']),
#        list(['love series enjoy ', 'talk speaker microphone send text']),
#        list(['', 'galaxy active even']),
#        list(['long time ', 'finally unending absolutely love']),
#        list(['tech experience ', 'active ', 'conveniency series']),
#        list(['teenage daughter ', 'version ', '', 'great']),
#        list(['bought ', 'wife early gift ', '', 'price']),
#        list(['buy awesome strong ', 'attractive lots']),
#        list(['everyday exception ', '', 'works ', 'super intuitive']),
#        list(['cant long cant leave house ', 'work life easy ', 'work']),
#        list(['love ', 'simplicity amazing simple ', 'understand']),
#        list(['favorite staff friendly ', 'helpful when']),
#        list(['series ', 'crack glad making affordable ', 'good option']),
#        list(['', 'heart ', 'blue color']),
#        list(['return item ', 'wife ', 'birthday ', 'sort time']),
#        list(['magnetic charging cable ', 'works perfectly plug port vehicle and']),
#        list(['pretty easy ', 'perfectly shipped ', 'happy purchase']),
#        list(['absolutely love gold stunning blue strap ', 'bought gold magnetic mesh for']),
#        list(['bought adapt charging cable connect traditional cable wall charger works perfectly']),
#        list(['love heart issue ', 'love ', 'check ', 'heart rate wonderful']),
#        list(['stopped working item hold charge replacement accomplished']),
#        list(['buy lot ', 'useless safe ', 'buy good']),
#        list(['pin attach broken ', 'strap fat fit slot ', 'insert']),
#        list(['return wrong size ', '', 'love shop buy store']),
#        list(['', 'great ', 'affordable alternative style simple ', 'sleek ', 'good ', 'price']),
#        list(['good experience ', 'than']),
#        list(['body ', 'removed star ', 'dirty quick ', 'resolved quick wash']),
#        list(['great alternative br', 'insignia phone ', 'works charger good price']),
#        list(['works ', 'phone easy connect ', 'music ', 'sleep time close']),
#        list(['series cant spot ', 'nice ', 'youve highly recommend']),
#        list(['replace ', 'broke good price paying ', '', 'dont']),
#        list(['great video ', 'easy setup great peace mind ', 'sending motion photo phone and']),
#        list(['great love ', 'turn water mode ', 'wear ', 'swimming longer battery life ', 'comparable']),
#        list(['bought product charge ', 'didnt box works designed ', 'price decent']),
#        list(['love health track fitness ', 'happier purchase']),
#        list(['charge ', 'sense love dont ', 'sense tho']),
#        list(['', 'wife wanting blue replacement ', '', '', '', '', 'great shape good buy']),
#        list(['love connect phone ', '', 'receive ', 'pickup phone']),
#        list(['skeptical series ', 'glad lot great specs love']),
#        list(['love worth extra money bought ', 'expensive ', 'love']),
#        list(['', 'absolutely fitness compatible easy cheap for']),
#        list(['sixth ', 'continuously rotate sons finish beautiful']),
#        list(['works good phone life lot easier pick phone morning text']),
#        list(['husb', 'doesnt wear wrist ', 'inspire purchase fit ', 'happy']),
#        list(['protect great ', 'piece mind worry ', 'great']),
#        list(['expect comfortable ', 'easy set battery life great']),
#        list(['tool wife heart rate ', 'sleep great tool ', 'communication']),
#        list(['smart ', '', 'stays ', 'future smart']),
#        list(['works fully easy set display nice bedroom bright night']),
#        list(['great fit downfall ', 'heat ', 'day']),
#        list(['gorgeous formal ', 'casual comfortable wear product']),
#        list(['charge ', 'key sell for']),
#        list(['great works great ', 'track walking ', 'activity great purchase ', 'highly recommend ', 'activity']),
#        list(['love series worried ', 'spending money ', 'immeasurable']),
#        list(['husb', 'happy ', 'doesnt ', '', 'good alternative']),
#        list(['tough phone charger connection ', 'works great ', 'love ', 'throw charge']),
#        list(['', 'great face covered ', 'impede touch']),
#        list(['switched brand']),
#        list(['charger ', '', 'traveling works great ', 'short cord tripping charging cord']),
#        list(['received ', 'love easy ', 'user recommend']),
#        list(['', 'wonderful idea ', '', 'good']),
#        list(['', 'daughter wasnt expensive ', 'pretty loving']),
#        list(['great smart ', 'shame fisher smart listen millennial']),
#        list(['original finally stopped working bought ', 'love ', 'than']),
#        list(['inspire easier ', 'wear ', 'bracelet style great ', 'counting ', 'keeping']),
#        list(['doesnt ', '', '', 'effective listening music pain']),
#        list(['series awesome ', '', '', 'amazing daily']),
#        list(['bought ', 'style satisfied battery doesnt']),
#        list(['love accidentally washer ', 'works ', 'soaked convenient check and']),
#        list(['series ', 'decided upgrade series great upgrade ', 'battery life opinion great']),
#        list(['bought ', 'daughter replace faster works great ', '', 'loving']),
#        list(['neat ', 'price battery life excellent text great product']),
#        list(['', 'family ', 'sleep analysis ', 'day']),
#        list(['', 'pay ', 'nice ease attractive']),
#        list(['great ', 'love display nice glance raise wrist battery day']),
#        list(['works great box series bigger millimeter face user friendly']),
#        list(['', 'works awesome mac ', 'love unlock']),
#        list(['', 'fitness ', 'amazing that']),
#        list(['bought replace great ', '', 'heart rate ring doorbell']),
#        list(['', 'days single charge battery life ', '', 'main reason switched']),
#        list(['order ', '', 'love ', 'order bought ', 'great']),
#        list(['enjoy ', 'wear daily close great ', 'generation']),
#        list(['time wear ', 'professional atmosphere people ', 'price']),
#        list(['', 'wrist breaking rash wearing original comfortable ', 'reaction']),
#        list(['love replace ', 'faster battery life tho workout counting accurate']),
#        list(['time ', 'glad love easy set ', '', 'everyday']),
#        list(['original ', 'falling wonderful replacement reasonable price']),
#        list(['dont lived life great ', 'healthy dont regret buy']),
#        list(['love ', 'long standing ', 'waterproof swim problem']),
#        list(['cant leave house phone ', 'cycle service buy excellent']),
#        list(['love ', 'times ', 'cellular version ', '', 'ozone']),
#        list(['didnt charge happy wear lot ', 'doesnt long charge']),
#        list(['saved ', 'forgot ', 'catching softball game']),
#        list(['love convenient ', 'pull phone purse straight phone']),
#        list(['love day ', 'dont wear handy ', '', 'text change music and']),
#        list(['series ', 'great choice fast series ', '', 'bigger display game changer']),
#        list(['cannot nice ', 'price ', 'extra bar nicely highly recommend']),
#        list(['perfectly super sleek ', 'col', 'comfortable wear day']),
#        list(['', 'birthday absolutely works great battery life ', 'deal breaker']),
#        list(['love super practical device mind built wearing android operating']),
#        list(['', '', 'and']),
#        list(['sooner ', 'works seamlessly great product']),
#        list(['wrong voice phone camera remote fitness tracker nice ', 'device']),
#        list(['love play music ', 'lots gear fit']),
#        list(['picked ', 'daughter ', 'birthday worn ', '', 'track sleep']),
#        list(['great wireless charging pad ', 'multiple wont work ', 'didnt for']),
#        list(['love product problem charge series long time']),
#        list(['love love love great series series love h', 'wash ', 'heart oxygen']),
#        list(['love operation ', 'fit replace older ', 'face']),
#        list(['', 'finally convenience life worth price']),
#        list(['functional charger nice design bought ', '', 'priced recommend']),
#        list(['great buy ', 'convenient bought fitness track ', 'ton cool']),
#        list(['spare charger ', 'works great ', 'faster ', 'originally regularly']),
#        list(['instinct ', 'learn ', 'easy start great']),
#        list(['wife ', '', '', 'display']),
#        list(['', 'wife ', 'nice soft touch material ', 'breathe']),
#        list(['great price charge ', 'great ', 'fitness ', 'plenty teacher']),
#        list(['series charging cable charger daily built good']),
#        list(['love easier ', 'easier keeping track heart rate ', 'spinning']),
#        list(['inspire ordered stopped working ', 'couple received ', 'longer works']),
#        list(['lots air ', 'felt cheap worth spent removed after']),
#        list(['series charge device']),
#        list(['horrible charge ', 'doesnt work phone ', 'worth price highly disappointed']),
#        list(['year ', 'charge quit working ', 'success work ', '', 'reset']),
#        list(['buy account ', '', '', 'days business']),
#        list(['disappointed edge peeled ', '', 'dirt stick']),
#        list(['son ', 'arm itch recommend']),
#        list(['works gen smart current cable ', 'kick bucket']),
#        list(['series economically cheap ', 'latest series']),
#        list(['great fit ', 'spot ', 'catching ', '', 'item great']),
#        list(['', 'great great stiff ', 'happy']),
#        list(['love husb', 'col', 'ways product amazing price tag steep ', '', 'pay for']),
#        list(['happy good love cellular ', '', 'walking nice music carrying phone']),
#        list(['love lot ', 'fit bit ', 'worth price totally enjoy']),
#        list(['catalyst ', 'great product protect']),
#        list(['', 'standard solid ', '', 'comfortable because']),
#        list(['lost original charge small ', 'great wear everyday']),
#        list(['specially ', 'work physically pull phone text']),
#        list(['love ', 'stay fit moment breathe ', 'heart health dope']),
#        list(['series silver aluminum white sport silver aluminum bought ', 'daughter love']),
#        list(['item bathroom love ', '', 'plug ', 'charging phone and']),
#        list(['love perfect love great price good fit ', 'tech ', 'user friendly']),
#        list(['', 'whatnot ', 'time ', 'halo contender']),
#        list(['', '', 'love glad switched ', 'decided upgrade']),
#        list(['sharp simple clean design easy perfectly ', 'wrist col', 'gorgeous']),
#        list(['gift fir wife ', '', '', '', 'happen light ', 'sleek']),
#        list(['buy love series busy workout reminder ', 'love happy that']),
#        list(['excellent android though wont beat android phone ', 'price option']),
#        list(['love gift ', 'recipient hard ', 'great entry']),
#        list(['love cant wrong ', '', '', 'smart']),
#        list(['convenient ', 'driving easy answer ', 'heart rate ', 'daily']),
#        list(['', 'love perfect ', '', 'happy']),
#        list(['', 'partial day ', 'work animal hospital ', 'when']),
#        list(['happy bigger ', 'battery life great and']),
#        list(['charge ', '', '', '', '', 'love ', 'style']),
#        list(['love light cooler ', 'summer ', 'open box']),
#        list(['series edition flawless music ', 'carrying phone']),
#        list(['series great luxury work life easier idea ', 'learning day']),
#        list(['cake highly ', 'choosing ', 'fit bit love sleekness ', 'phone']),
#        list(['stay connected expensive luxury ', '', 'time fav', 'buy']),
#        list(['', '', 'ring nice ', '', 'feel ', 'informed']),
#        list(['glad buy bigger sale ', 'time works great recommend']),
#        list(['love initially ', 'fit bit saved']),
#        list(['', '', '', 'long pretty good']),
#        list(['love wear ', 'everyday ', 'quick lot great ', 'specs']),
#        list(['ionic ', 'stopped charging ', 'warranty ', 'liking']),
#        list(['great ', 'longer offering ', 'strange']),
#        list(['love easier ', 'previous charge clock enjoying']),
#        list(['paired easily works great cute bumper ', 'protect investment']),
#        list(['', 'buy adapter ', 'easy buy ', 'wasnt included']),
#        list(['great latest technology ease ', 'data fabulous highly recommend']),
#        list(['bigger good battery ', 'but']),
#        list(['amazing ', 'change display time ', 'heartbeat']),
#        list(['', 'good price ', 'purchase but']),
#        list(['husb', 'expensive ', 'job ', 'perfect for']),
#        list(['wanting ', 'a', '', 'love purchase sleek ', 'easy']),
#        list(['love ', 'high ', 'col', 'fade good nut ', 'price']),
#        list(['love product ', '', 'cant imagine ', 'when']),
#        list(['works compliment charger series power adapter']),
#        list(['bought record ', '', 'great job love']),
#        list(['super amazing wanting track ', 'long spending affordable ', 'reliable great purchase']),
#        list(['bought ', 'mother ', 'fancy ', 'track great product']),
#        list(['comfortable ', 'ventilation great ', 'exercise highly recommend for']),
#        list(['bought ', 'sons birthday didnt bought buy']),
#        list(['bought fit ear ', 'wear hearing works great work sound fantastic']),
#        list(['love perfect ', '', '', '', 'running calorie counting ', 'phone']),
#        list(['bought series silver aluminum white sport silver aluminum product ', 'performance awesome']),
#        list(['', 'job ', 'fancy']),
#        list(['', 'felt upgrade hearing alert ', 'great']),
#        list(['daughter ', 'family ', 'service cant wrong']),
#        list(['', 'long time gift love negative charge nightly']),
#        list(['protect ', 'expensive works good ', 'face ', 'place']),
#        list(['good basic series extra functionality series great price point ', 'sale that']),
#        list(['original difference loving fast charge death fully']),
#        list(['series ', '', '', 'bought ', 'year dad ', 'birthday loving']),
#        list(['love push ', 'helpful dont phone sitting desk']),
#        list(['face ', '', 'continually replace even']),
#        list(['', '', '', 'when']),
#        list(['love battery life great ', 'days charging sleep and']),
#        list(['charge good additional happy purchase']),
#        list(['', '', '', 'hesitant wouldnt bulk small great ', 'love']),
#        list(['good ', 'good price ', 'decent scratches ', 'set for']),
#        list(['series stainless steel nice ', 'stainless steel']),
#        list(['h', '', 'series continue purchase love ', 'busy and']),
#        list(['', 'loving drive lot ', 'navigation notified turns ', 'location dont']),
#        list(['awesome staff informative purchase love easy maneuver ', 'understand']),
#        list(['loving didnt ', 'expensive ', '', 'pay ', 'and']),
#        list(['easy install strap hold wear play basketball ', 'undone easy remove ', 'wash']),
#        list(['wife everyday ', 'exercise ', 'and']),
#        list(['great charger connected anker travel st', 'change phone pro ', 'simultaneously']),
#        list(['decided buy ', 'health scare heart rate monit', '', 'built monit', 'health']),
#        list(['adapter ', 'charger connect cable older power charger block item job']),
#        list(['family love sleek ', 'functionality ', 'spouse ', 'birthday']),
#        list(['love ', 'sport black sports enjoy screening cell phone neat ', 'face']),
#        list(['wanting ', 'time ', 'finally bit bullet amazing completely satisfied purchase']),
#        list(['received ', 'original beware electronics for']),
#        list(['sport duo ', 'dont bother worth money great ', 'couple falling']),
#        list(['product worthless glass stay ', 'rubber bumper issue ', 'worse']),
#        list(['ironman ', 'worked completely die box']),
#        list(['returned ', 'bought happier subscribe monthly didnt ', 'idea']),
#        list(['waste money returned couple days reach told']),
#        list(['batter doesnt days']),
#        list(['good product ', 'trouble product ', 'time couple small that']),
#        list(['learning havent ', 'gen love oxygen ', 'heart rate battery life']),
#        list(['silicone ', 'broke ', 'year ', 'multiple adjustment']),
#        list(['works ', '', 'buck ', '', 'wore and']),
#        list(['good month buy associate install series ', 'worked']),
#        list(['love charge happy program insurance love ', 'built']),
#        list(['working fine whatsoever easy ', 'rarely actual restart viper button']),
#        list(['', 'fraction money missing written ', 'figure']),
#        list(['goodness naked ', 'cant live device wrist']),
#        list(['sharp simple clean design charge perfectly ', 'wrist stylish ', 'love color']),
#        list(['bought ', 'birthday ', 'everyday fitness fitness']),
#        list(['love series ', 'user friendly ', '', 'fall bang']),
#        list(['smart ', 'android ', 'compare display']),
#        list(['device perfectly wahoo fitness phone ', 'construction update review after']),
#        list(['small wrist ', 'perfectly love carbon fiber pretty nice ', 'bulky']),
#        list(['sport breathable ', 'standard sport wrist doesnt feel sweaty']),
#        list(['smart love ', 'active activity program']),
#        list(['works great ', 'charger ', 'stable night st', 'charge fast']),
#        list(['amazing ', 'perfectly ', 'ventilation']),
#        list(['love everyday track check ', 'sleep night check sleep']),
#        list(['loving upgrade charge ', 'stopped working ', 'crossing']),
#        list(['', 'market ', 'great and']),
#        list(['', '', '', '', 'decided process simple ', 'happier']),
#        list(['simple box feel phone properly even']),
#        list(['big fan love option wrist nicely ', 'enjoy compass series']),
#        list(['love order ', 'disappointed long ', 'good price ', 'buy good job']),
#        list(['charger works ', 'quick great ', 'purse small bag']),
#        list(['perfect lightweight dont ', '', 'easier']),
#        list(['happy charge step charge glad dont constantly shower']),
#        list(['prefer series ', 'battery life didnt ', 'form fact', 'series']),
#        list(['', 'learning time ', 'and']),
#        list(['nice upgrade ', 'option face plate choose']),
#        list(['love integration wireless charging ', 'charging capability slot charge item']),
#        list(['buy ', 'glad bought colors great ', 'easy durable ', 'thought']),
#        list(['class series excellent market highly recommend market']),
#        list(['love works handy recall ', 'hurry lot ', 'phone']),
#        list(['upgrade great smooth ', 'sailing ', 'bought hooked ', 'process']),
#        list(['works great tough hook ', '', 'easy ', 'accurate lot than']),
#        list(['love ', 'learning happy']),
#        list(['helpful ', 'battery longer making day keeping charger handy boost']),
#        list(['long ', 'food turns perfect time ', 'easy phone']),
#        list(['bought ', 'son gift ', '', 'year convinced purchase']),
#        list(['', '', 'exercise regimen ', 'feedback performance filled void']),
#        list(['real ', 'real great ', 'design ', 'awesome']),
#        list(['nice strong leather beautiful perfect ', 'highly recommend product job']),
#        list(['wasnt ', 'realize dont carry phone time']),
#        list(['excellent fitness main fact', '', 'track ', 'walk day']),
#        list(['ordered col', 'variety charge ', 'great easy ', '', 'nice colors']),
#        list(['clutter ', '', 'fall night st', '', 'nice view night ', 'clock awesome product']),
#        list(['stylish everyday ', 'trick leave wrist sweaty traditional']),
#        list(['great ', 'recommend ', 'buy replacement']),
#        list(['preferred coverage bumper glass ', 'separate bumper ', 'glass protect face']),
#        list(['charger works great ', 'white scratch good buy ', 'good product']),
#        list(['upgrade series bit expensive']),
#        list(['', 'though series works great ', 'purpose ', '', 'extremely happy item']),
#        list(['replace gear ', 'love ', 'upgrade']),
#        list(['', 'option ', 'function needing phone connected']),
#        list(['bought series silver aluminum white sport silver product ', 'performance awesome']),
#        list(['daughter ', 'family ', 'service wrong']),
#        list(['inspire great tool ', 'honest ', 'active ', 'great cat face']),
#        list(['love ', 'love display ', 'day']),
#        list(['awesome product works ', 'fraction price ', 'year battery life great']),
#        list(['love generation ', '', 'love workout']),
#        list(['hard ', '', 'learn ordered for']),
#        list(['happy purchase buy price buy']),
#        list(['', 'battery life sleep']),
#        list(['form gift ', 'personal anniversary love extra ', 'phone']),
#        list(['', 'protect soft ', 'good job ', 'clear color']),
#        list(['previous original maj', 'upgrade great battery life and']),
#        list(['', 'fitted budget ', 'long time finally ', 'happier']),
#        list(['', 'wife ', 'daily battery life comfort ', 'ease']),
#        list(['love series easy ', 'lot ', 'enjoy experience great']),
#        list(['told gift ', 'owner ', 'set ', 'personal']),
#        list(['sleep good ', '', 'battery doesnt days ', 'enjoying']),
#        list(['regular user ', 'type work access text phone']),
#        list(['love charger ', 'turning ', 'forgotten fully charge morning']),
#        list(['enhance ', 'magnetic ', 'easy buy product color']),
#        list(['love buckle easier ', 'secure price opinion ', 'for']),
#        list(['generation ', '', 'picked ', 'didnt health']),
#        list(['', 'charge ', 'week accurate ', 'amazing']),
#        list(['love inspire wrist small ', 'slender time ', 'description']),
#        list(['beautiful ', 'great material ', 'great white ', 'feel']),
#        list(['charge ', 'version exercise sleep heart rate and']),
#        list(['high build ', '', 'infinitely adjustable fit works ', '', 'nice instantly']),
#        list(['great ', '', 'flash ', 'podium']), list(['love and']),
#        list(['aware ', 'special charging brick grateful ', 'representative told ', 'and']),
#        list(['love ', 'a', '', 'finally decided easy set ', 'than']),
#        list(['bought alternative work ', 'received ', 'turned ', 'charging night']),
#        list(['bought ', '', 'plastic ', 'for']),
#        list(['coating chipped day device po', 'appearance']),
#        list(['easily ', 'bought ionic absolutely ', 'horrendous phone support']),
#        list(['good ', 'heavy ', 'snaps hair waterproof that']),
#        list(['good tracker ', 'extra ', 'good device ', 'than']),
#        list(['work great didnt ', 'dont completely ', 'learning ', 'enjoying']),
#        list(['', 'easy ', '', 'nice tech material soft durable ', 'playable']),
#        list(['love time smaller ', 'series bigger display what']),
#        list(['good coverage ', 'min', '', 'visible charge responsive']),
#        list(['walk breeze sound good cutting ', 'hindrance good']),
#        list(['active ', '', 'easier ', 'previous gear pro ', '', 'and']),
#        list(['', 'version time ', '', 'while']),
#        list(['protect ', 'ended reckless']),
#        list(['seni', 'knowing oxygen level ', 'heat rate close']),
#        list(['great product ', 'active ', 'overly active individual love connect ', 'track activity ', 'price than']),
#        list(['love love love version daughter']),
#        list(['purchase hope open battery']),
#        list(['track health ', 'lost lot weight awesome ', 'highly recommend ', '', 'perfect']),
#        list(['browser support video moving ', 'walking treadmill morning week']),
#        list(['extra charger ', 'charge ', 'car ', 'traveling ', 'and']),
#        list(['fantastic ', 'send text ', '', 'and']),
#        list(['love ', 'dime ', 'g', '', 'birthday extra ', 'bigger']),
#        list(['bought open box ', 'received practically absolutely love accountable ', '', 'shape']),
#        list(['fitness ', 'generation fitness journey losing']),
#        list(['good ', 'reliable ', 'job ', '', 'highly recommend']),
#        list(['love received gift ', 'ended ', 'year son works great ', 'nice']),
#        list(['gift purchase ', 'husb', 'love price tag']),
#        list(['game changer ', 'phone charger bonus ', 'charge flying night stand']),
#        list(['', 'charge good fit easy apply ', 'scratching hard ', 'rough']),
#        list(['perfect gift ', 'wife happy product excellent buy fine perfect gift']),
#        list(['house charger ', 'phone']),
#        list(['', 'loving easy great ', 'love ', 'fitness free for']),
#        list(['excellent warm handle grip original coupling perfect col', 'remains']),
#        list(['charge heart rate active']),
#        list(['', 'great condition ', 'durable protect ', 'great price']),
#        list(['love phone ', 'physical ', 'work harder day']),
#        list(['reason dont ', '', '', 'working']),
#        list(['worth buy simple beautiful ', 'great ', 'and']),
#        list(['great comfortable ', 'sporty bought sale good deal regular price expensive ', '', 'pay for']),
#        list(['perfect material ', 'stays cool ', 'great sizing ', '', 'that']),
#        list(['bought ', 'birthday replace ', 'easier read']),
#        list(['', 'smart decided easy set ', 'extra workout ', 'health']),
#        list(['love galaxy active seamlessly phone ', 'working ', 'phone breeze']),
#        list(['protect sale ', '', 'good item']),
#        list(['great size ', 'superb battery life ', '', 'big ', 'track ', 'heart rate']),
#        list(['son wanting finally perfect ', 'pay extra ', 'series works great']),
#        list(['love upset reward ', 'dont buy']),
#        list(['received birthday gift wall charger buy charger store ', 'purchase ', 'day']),
#        list(['decided stainless steel version glad love weight ', 'feel series']),
#        list(['touch ', 'nice ', 'son lot bright']),
#        list(['original series ', 'love love swim']),
#        list(['', 'lite ', '', '', 'love ', 'change easily']),
#        list(['', 'satisfied works ', '', 'problem wearing day']),
#        list(['', 'feel great ', 'easy stays ', 'great warranty program']),
#        list(['', 'perfect condition love for']),
#        list(['', 'battery life']),
#        list(['sport ', 'brown ', 'light blue killer orange picture dont justice']),
#        list(['perfect ', '', '', '', 'works excellent wont complete easy install ', 'setup']),
#        list(['love battery life love ', 'wrist love']),
#        list(['', 'ape days ', 'sturdy ', 'high tech time great awesome purchase']),
#        list(['bought ', 'wife leather ', 'great size']),
#        list(['', '', 'helpful easy ', 'fitness']),
#        list(['super cute people ', '', 'people']),
#        list(['', 'birthday absolutely easy program battery life awesome highly recommend']),
#        list(['', 'regular exercise schedule aware sleep hygiene']),
#        list(['', 'easy ', 'pristine shape']),
#        list(['perfect condition ', 'works perfectly fine loving ', 'nice faster ', 'thought']),
#        list(['happy purchase price buy']),
#        list(['wore ', 'though ', 'change while']),
#        list(['bought ionic ', 'husb', '', 'day ', 'upgrade previous']),
#        list(['', 'hesitant update price ', 'open product price bought']),
#        list(['', '', '', '', 'didnt perfect']),
#        list(['love price simple bought ', 'stretch']),
#        list(['version ', 'great price ', '', 'col', 'great']),
#        list(['', '', 'comfortable accurate ', 'easy stays ', 'week']),
#        list(['worked beautifully ', 'saved charge happy product ', 'fit perfect ', 'saving time ', 'money']),
#        list(['works ', 'wireless charging small ', 'light ', '', 'small love']),
#        list(['good times ', 'highly recommend wearer']),
#        list(['product ', 'charge phone ', 'phone phone while']),
#        list(['love fast easy battery life long charge ', 'day']),
#        list(['beating absolute purchase ', '', 'price cant wrong']),
#        list(['love ', 'charge doesnt long bur charge ', 'leave house morning']),
#        list(['charge charge ', '', 'love bought']),
#        list(['col', '', 'rose col', '', '', 'shiny sliver col', '', 'love']),
#        list(['simple ', 'sophisticated comfortable ', '', 'sophisticated']),
#        list(['great ', 'nice ', 'save lot money highly recommend']),
#        list(['good cheap good ', 'super cheap ', 'battery ', 'days and']),
#        list(['multiple smart ', '', 'track health ', 'sleep']),
#        list(['previous happy love ', 'dont phone nearby for']),
#        list(['favorite sport col', 'aquamarine blue ', 'green ', '', '', 'usual']),
#        list(['chose works phone ', 'send text listen music']),
#        list(['love ', 'stainless steel mesh enjoy screening cell phone neat ', 'face']),
#        list(['husb', '', 'super light weight easy clean ', 'great ', 'works outdoors']),
#        list(['easy install shorten ', 'easy shorten beautiful rose gold color']),
#        list(['', 'easy ', 'year ', 'longer warranty smart durable']),
#        list(['', '', 'cost absolutely useless product']),
#        list(['bought ', 'charger working portion holder ', 'charger product']),
#        list(['inspire lunar white good hard set son ', 'return set']),
#        list(['horrible cheap knock buy data secure ', 'read']),
#        list(['nice party play store switched ', 'comparison']),
#        list(['great ', 'price ', 'returned ', 'cellular ', '', '', 'kind than']),
#        list(['previous series ', 'satisfied love display busy']),
#        list(['love inspire wasnt sleep ', 'helpful mobile easy ', 'convenient']),
#        list(['skeptical ', '', 'wondering procrastinating']),
#        list(['highly recommend buy upgrade display nice ', 'battery long lasting']),
#        list(['awesome ', 'medical ', 'easy ', 'blue cool']),
#        list(['series cellular cellular connect family ', 'and']),
#        list(['absolutely love buy pick perfect ', 'patient']),
#        list(['awesome purchase sale great purchase ', 'easy buy']),
#        list(['great ', '', 'mix wine metal mesh ', 'silicone']),
#        list(['speak ', 'battery good ', 'works fine']),
#        list(['long time series bit worth money love awesome']),
#        list(['great comfortable approach ', 'that']),
#        list(['thinking series ', '', '', 'understood ', 'now']),
#        list(['husb', '', 'charge longer ', 'nice']),
#        list(['switched galaxy ', 'dont regret ', 'awesome battery life amazing ', 'love']),
#        list(['sharp simple clean design easy perfectly ', 'col', 'gorgeous']),
#        list(['', 'cant showing amazing piece technology ', 'great battery life']),
#        list(['', 'waterproof ', 'opportunity ', 'swimming']),
#        list(['great love text ', 'phone leaving stay free']),
#        list(['love phone ', 'return bulky ', 'great']),
#        list(['awesome product received gift ', '', 'received ', 'live']),
#        list(['strong strap felt durable ', 'easily cleanable ', '', 'lite broke set strap good ', 'money']),
#        list(['recommend ', 'price ', 'functionality interface easy ', 'which']),
#        list(['works fully set nice bedroom bright night']),
#        list(['genuine leather strap ', 'excellent price series perfectly pink col', 'gold color']),
#        list(['love product ', 'couple ', 'enjoy works great ', '', 'physical activity']),
#        list(['love ', '', 'light night ', 'track sleep handy']),
#        list(['super easy ', 'feel ', 'protect expensive collect bit dust ', 'easily ', 'wipe clean']),
#        list(['charge easier set activity charge swipes set start activity and']),
#        list(['super easy ', 'love avid runner ', 'than']),
#        list(['great coming huge upgrade ', 'love display fantastic ', 'easy setup works phone']),
#        list(['product time great shape ', '', 'organized ', 'provide area charge phone and']),
#        list(['great product works sleep water ', 'food check weather ', 'receive text']),
#        list(['perfect upgrade series ', 'decided treat dont regret purchase love']),
#        list(['great fit perfectly ', '', 'fraction cost highly recommend']),
#        list(['original charger ', 'broke bought replace ', 'worked great great price']),
#        list(['debating ', '', 'glad plan son ', 'version']),
#        list(['absolutely love ', '', '', 'super convenient ', 'love fitness option']),
#        list(['wow great barely ', '', 'sale jump exquisite']),
#        list(['happy ', 'battery life functionality']),
#        list(['', '', 'charge feel ', 'longer ', '', 'charge']),
#        list(['love big ', 'worth price and']),
#        list(['', 'times year jump ', 'happy highly recommend']),
#        list(['upgrade ', 'archaic ', 'previous generation higher']),
#        list(['athlete outdo', 'adventurer general sports fitness enthusiast great']),
#        list(['', 'replacement ', 'charge col', 'vibrant easy ', 'wash clean']),
#        list(['bought ', 'heart ', 'movement love']),
#        list(['favorite battery life infinitely longer ', 'comfortable ', 'easy']),
#        list(['bumper gold ', 'saved ', 'scratches accident prone highly recommend']),
#        list(['love birthday wear everyday day love']),
#        list(['work ', 'time reply message phone handy reply']),
#        list(['good ', 'product ', '', 'what']),
#        list(['nice inexpensive charger worked ', 'wife pinch ', 'forgot charger ', 'heading town pickup great']),
#        list(['gifted wife ', '', 'ecstatic ', 'highly than']),
#        list(['user friendly basic light weight ', 'easy bind phone ', 'love heavy and']),
#        list(['series excellent heart rating breathing ', 'time stand']),
#        list(['double mouse pad banging edge ', '', 'price']),
#        list(['good bumper style ', 'dirty work ', '', 'replace']),
#        list(['blaze day battery life ', 'picked ', 'clock and']),
#        list(['hubby easy battery charge day for']),
#        list(['love comfortable wear great easy clean ', 'wrist highly recommend']),
#        list(['', 'buy ', 'price ', 'time ', '', '', 'track activity ', 'ensure stay healthy']),
#        list(['long time ', 'finally unending absolutely love']),
#        list(['good product ', 'deaf people ', '', '', 'signal']),
#        list(['love glad bought phone ', 'calling ', 'respond text']),
#        list(['love heart monit', '', 'peace mind medium wrist ', 'perfect']),
#        list(['upgrade daughter communicate phone ', 'didnt huge price tag perfect option']),
#        list(['love headset big upgrade gear advice ', 'buy halo headset provide uncomfortable']),
#        list(['modal silicone ', 'blue daughter durable water bought colors']),
#        list(['lost didnt buy']),
#        list(['great helpful ', 'work ', '', 'breathe ', 'road drive manual car']),
#        list(['purchase ', 'happy price ', 'service received knowledgeable ', 'friendly']),
#        list(['bought ', 'wife dresser ', 'fit feel ', 'appearance purchase']),
#        list(['good ', 'wife works ', 'recommend friend']),
#        list(['charge ', 'summer ', '', 'absolutely tracker']),
#        list(['happy inspire ', 'slim ', 'sleek battery charge ', 'long time today']),
#        list(['works great ', 'quick charge super bright ', 'nice cable charger ', 'worked']),
#        list(['love young lady ', 'outstanding job knew product ', '', 'priced']),
#        list(['charge replace nice ', '', 'fall']),
#        list(['long overdue ', 'refresh series ultra ', 'change love design and']),
#        list(['great battery life days solid charge size big ', 'feel big wrist']),
#        list(['sense charge ', 'love ', 'moving and']),
#        list(['replace week ', 'happy ', 'daily']),
#        list(['absolutely love ', 'super comfy ', 'glad chose']),
#        list(['work ', '', 'though description black edge ', 'display']),
#        list(['work ', 'plastic sticky ', 'easy ', 'drawing board']),
#        list(['longer works dead ', 'normal bought ', 'birthday unfortunate mistake purchase']),
#        list(['', 'good work ', '', 'slow ', '', 'returned and']),
#        list(['mood doesnt work wrist hurt wear long lack feedback device hard track progress']),
#        list(['product time bought gift ', 'daughter ', 'didnt ', 'mommy']),
#        list(['bought replace ', 'great ', '', 'accurate lack annoying']),
#        list(['great rose gold downside ', 'material ', 'breathable sweat']),
#        list(['love series smooth ', 'flawlessly series ', 'meant']),
#        list(['item ', '', 'nice ', 'expensive ', 'expensive']),
#        list(['easy fan ', 'absolutely love special ', 'work dont carry phone']),
#        list(['good col', 'awesome disappointed ', 'area colors washed ', 'brilliant']),
#        list(['wasnt long ', 'wrist ', 'responsive version big upgrade charge']),
#        list(['love galaxy switch ', 'times stuck outdated ways paying outrageous ', 'limited']),
#        list(['', 'issue ', 'cannot resolve face']),
#        list(['love track physical activity ', 'love ', '', 'text message coming']),
#        list(['easily ', 'doesnt interfere cheap ', 'sturdy ', 'peace mind knowing']),
#        list(['charge love ', 'wearing ', 'love flexibility']),
#        list(['inspire fitness tracker black great birthday gift easy good recommend']),
#        list(['good ', 'series ', 'worried scratches ', 'naked']),
#        list(['love ', '', '', 'year glad finally']),
#        list(['great power strip ', '', 'traveling ', '', 'phone tablet speaker and']),
#        list(['great deal stainless model high product ', 'upgrade improvement battery life day for']),
#        list(['daughter ', 'favorite col', 'mint green good price ', 'perfect fit ', 'series']),
#        list(['love series series ', 'good series bought br', 'great price']),
#        list(['', 'wife wanting blue replacement ', '', '', '', '', 'great shape good buy']),
#        list(['bad works perfectly fine ', '', 'save money easy setup love']),
#        list(['', '', 'absolutely love battery life good ', 'charging for']),
#        list(['', 'clean ', 'smooth fake ', 'plastic turn yellow']),
#        list(['set ', 'hooked phone person busy good service']),
#        list(['daughter perfect ', 'active love bouldering rock climbing ', 'col', 'for']),
#        list(['expect comfortable ', 'easy set battery life great']),
#        list(['love ready latest version ', 'funds recommend ', '', 'health and']),
#        list(['love choice purchase buy ', 'store']),
#        list(['gifted hubby ', '', 'light ', 'notice wearing']),
#        list(['permanent fixture easy ', 'attached gen']),
#        list(['great ', 'water ', 'scratches year great']),
#        list(['great ', 'perfectly ', 'sense peace ', 'phone surface']),
#        list(['unsurpassed ', 'tech great buy']),
#        list(['', 'st', 'charge ', 'idea ', 'time ', 'charging']),
#        list(['tough phone charger connection ', 'works great ', 'love ', 'throw charge']),
#        list(['pretty ', 'lot but']),
#        list(['', '', 'everyday ', 'feel lost glad finally decided purchase']),
#        list(['easy set ', 'stylish niece']),
#        list(['', 'ionic torn replacement item perfect ', '', 'color']),
#        list(['great ', 'good ', 'series snappy ', 'works great']),
#        list(['series daughter ', '', 'version ', 'birthday']),
#        list(['love love great ', 'love ', 'recommend']),
#        list(['bought health ', '', 'love wear single day but']),
#        list(['love ', 'calling ', 'pretty dose dose']),
#        list(['love change feeling love col', 'and']),
#        list(['love upgrade series love bigger ', 'love ', 'keyboard ', 'text']),
#        list(['love rocking ', 'addition ', 'amazing comfortable ', 'stylish']),
#        list(['series great buy easy ', 'delay lag works great regret']),
#        list(['love enjoying time ', 'design purchase ', 'teen ', '', 'love']),
#        list(['waiting ', 'watchless fit bit premium battery life sold']),
#        list(['love works ', 'phone reaching ', 'phone set easy ', 'nice']),
#        list(['son bought ', 'aunt ', 'flag colors support good']),
#        list(['year ', '', 'great everyday great purchase love bought']),
#        list(['absolutely love ', 'smart bit learning curve ', 'feel pretty comfortable now']),
#        list(['love sleek ', 'convenience literally kind product buy']),
#        list(['series works great love ', 'daily battery longer ', 'day ', '', 'love']),
#        list(['love pro easy ', 'love touch recognition ', 'connection unlock great']),
#        list(['', 'son ', 'absolutely ', 'ready ', '', 'awesome alternative']),
#        list(['simple lot option company']),
#        list(['approach ', 'depend shot measuring pin actual location ', 'scoring good']),
#        list(['nice bike ', 'peloton works great magnetic resistance ', 'worth buy']),
#        list(['', 'price hybrid leather worth nice ', 'nice recommend']),
#        list(['great video pack excellent great length highly recommend ', 'mon item lots fun multiple times']),
#        list(['excellent light weight ', 'accurate reading husb', '', 'than']),
#        list(['', '', 'nice ', 'easy links adjust wrist']),
#        list(['love silver version series ', 'broke black ', 'clean finish']),
#        list(['combination cell phone ', 'st', 'sturdy ', 'great ', 'price highly recommend']),
#        list(['', '', 'health ', 'phone ', 'great start ', 'long time']),
#        list(['love series smooth ', 'flawlessly series ', 'meant']),
#        list(['love ', 'track step ', 'recommend love']),
#        list(['great workout tracker nice display satisfied purchase ', 'glad saved extra']),
#        list(['bought ', 'son ', 'work ', 'great product']),
#        list(['love beautifully built piece love ', 'time lift arm']),
#        list(['', 'series ', 'series highly recommend ', 'battery life greatly worth upgrade']),
#        list(['series great love ', 'text amazing glance love']),
#        list(['comfortable great silver col', 'beautiful ', 'great great combination colors']),
#        list(['happy charge comfortable wear wrist ', 'display pretty tough item']),
#        list(['', 'wife ', 'works great ', 'easy ', 'product credit ', 'mindfulness']),
# ...
#        list(['super easy ', 'pool ', 'great ', 'summer ', 'wrist heat ', 'humidity']),
#        list(['wonderful monit', 'love ', '', 'phone works']),
#        list(['', '', 'love great product problem battery life ', '', '', 'complaint']),
#        list(['love check heart rate ', 'check heart ', 'fib awesome access check heart rhythm']),
#        list(['love ', 'moving ', 'hit gym']),
#        list(['', '', '', 'hesitant bulk small great ', 'love']),
#        list(['favorite charger car ', 'charge stunning easy ', 'word pro']),
#        list(['works ', 'stopped working great backup charger ', 'expensive branded']),
#        list(['great deal everyday personal trainer ', 'helpful love track compete']),
#        list(['oxygen meter accurate ', 'heart rate reading accurate works ', 'and']),
#        list(['', 'love favorite ', 'st', 'goal track fitness']),
#        list(['charge working great ', 'android accurate granite sweaty']),
#        list(['replace ', 'daily great replacement that']),
#        list(['switched ', 'switched ', 'love review']),
#        list(['love dont charge days days ', 'workout and']),
#        list(['decent bigger ', 'product recommend ', 'easy']),
#        list(['series good ', 'teens wanting sleek design performance great']),
#        list(['worth penny lot battery long time track sleep nice']),
#        list(['', 'bit decided mid price option love ', 'highly recommend']),
#        list(['great wireless charging solution ', '', 'phone single cable ', 'transformer included high feel']),
#        list(['enjoying lot ', '', 'learn']),
#        list(['happy size ', 'favorite love col', 'and']),
#        list(['sweet spot ', '', 'love great ', 'battery day']),
#        list(['easy ', 'button ', 'emergency number recommend item']),
#        list(['waste money works ', 'charge ', 'charger port fit properly piece']),
#        list(['return charge time charge phone time']),
#        list(['return expect remember correctly cant people trust connection']),
#        list(['great product ', '', 'functionality though and']),
#        list(['hold phone support adjustable phone small wallet great']),
#        list(['waiting purchase ', 'sale convenient battery longer']),
#        list(['fine great ', 'didnt ', 'fully good']),
#        list(['love wireless charger ', 'phone ', 'gear phone sitting properly lose wireless charge']),
#        list(['love ', 'disappointed graphics ', 'previous graphics ', 'times']),
#        list(['works pretty good problem ', 'easy access ', '', 'water']),
#        list(['', 'bigger nice battery life good ', 'day']),
#        list(['love track basic health blood majority what']),
#        list(['dont pay send pretty good doct', '', 'expensive']),
#        list(['love track ', 'day ', 'heart rate pretty accurate ', 'spot']),
#        list(['', 'user ', 'unnecessarily complex and']),
#        list(['perfect gift ', 'day literally wife arrive time and']),
#        list(['smaller prefer smaller size ', 'light wrist']),
#        list(['pretty straight ', 'practically universal ', 'nicely built charging cable']),
#        list(['great piece technology model ', 'huge difference loving level for']),
#        list(['enjoying tremendously ', '', 'daily days charge great']),
#        list(['good great built red col', 'beautiful metallic ', 'red recommend']),
#        list(['learn ', 'chose ', 'life alert']),
#        list(['small sleek ', 'accurate inspire love gemma mart small sleek ', 'accurate review']),
#        list(['', 'linked fit ', 'sale price good']),
#        list(['charge working ', 'set though older set']),
#        list(['', '', '', 'size issue ', 'awesome lots ', 'tough']),
#        list(['love size great fit perfect love ', 'cant quick phone time']),
#        list(['series ', 'receive easy ', 'record exercise routine']),
#        list(['absolutely love series ', 'keeping track totally addicted ', 'wear everyday']),
#        list(['great deal ', 'selling ', 'suppose good experience buy set broken']),
#        list(['love ', 'easier handle ', 'lot opinion']),
#        list(['love purchase ', 'stay organized ', 'active highly recommend']),
#        list(['love series fitness ', 'productive']),
#        list(['br', 'series ', '', 'size worth price works flawlessly ', 'sealed box']),
#        list(['series ', '', 'battery']),
#        list(['prefer original open box ', 'knock soft ', 'comfortable']),
#        list(['big fan love option wrist nicely ', 'enjoy compass series']),
#        list(['bought ', 'son ', 'col', 'blue ', 'change col', 'graduation']),
#        list(['lot series ', 'lot']),
#        list(['wear day everyday quick charge ', 'day absolutely ', 'since']),
#        list(['love love love ionic loyal customer ', '', 'device ', 'honestly favorite']),
#        list(['', 'husb', '', 'felt making phone wrist time partial disconnect']),
#        list(['', 'birthday ', '', 'works br', 'wrong buy']),
#        list(['love ', '', '', 'battery life great highly recommend']),
#        list(['super love ', '', 'didnt upgrade but']),
#        list(['version love bigger ', 'responsive series']),
#        list(['works fantastic box easy ', '', 'reasonable price']),
#        list(['cord perfect job efficiently ', 'portable change bit longer']),
#        list(['perfect bed table ', 'easy bed huge ', '', 'phone ', 'charge ', 'sleep']),
#        list(['nice strong leather beautiful perfect ', 'highly recommend product job']),
#        list(['series great ', 'health ', 'everyday life time']),
#        list(['gear ', 'pretty great sleep ', 'layer']),
#        list(['love ', 'price cant beat husb', 'paying ', 'data plan good']),
#        list(['lie super decided ', 'working ', 'working ', 'handy']),
#        list(['great addition ride ', 'stays tight vibration ', 'wind hesitate purchase']),
#        list(['finally ', 'sense charging station ', 'charge phone ', 'time convenient location']),
#        list(['gift ', 'love awesome ', 'flex highly']),
#        list(['', 'love love love big fan thinking disappointed']),
#        list(['love small size classic squared sleep work ', '', 'heart rate pretty ', 'good']),
#        list(['blaze ', 'switched glad disappointed']),
#        list(['inspire ', 'love wear time ', 'dont worry wet highly recommend device']),
#        list(['love works great air unlock cool that']),
#        list(['lot missing couple ', '', 'price match connection easy ', 'simple']),
#        list(['love ', 'discount buy ', 'easy purchase ', '', 'tech']),
#        list(['repair tech didnt absolutely product ', 'cant wait coming']),
#        list(['love ', 'break ', 'life chaotic nice reminder ', 'break']),
#        list(['purchase series ', 'battery life extra charge ', 'night']),
#        list(['', 'buy excellent talk ', 'work stopping work answer']),
#        list(['', 'wanting ', '', 'that']),
#        list(['high ', 'device control mechanism large dial']),
#        list(['replacement ', 'lost charge charge ', 'seek fitness monit', '', 'great']),
#        list(['love bought original working today love fantastic ', 'great health']),
#        list(['bought gift friend ', 'enjoying everyday highly recommend product']),
#        list(['enhance ', 'magnetic ', 'easy buy product color']),
#        list(['super convenient ', 'protecting table ', 'wall times ', 'damages glad purchase']),
#        list(['perfect ', '', '', '', 'recommend']),
#        list(['love bought ', 'series broke ', '', 'time ', 'upgrade']),
#        list(['pretty nice fitness stay ', 'for']),
#        list(['great stainless steel variance keeping ', 'spend money and']),
#        list(['clear bumper protect ', 'clear ', 'attractive col', 'visible']),
#        list(['love user friendly purchase ', 'style honest']),
#        list(['great tool ', 'link size ', 'tool ', 'time']),
#        list(['love bracelet comfortable ', 'stylish recommend ', 'style']),
#        list(['huge upgrade stylish ', 'works flawless ', 'big']),
#        list(['bought series ', 'starter comfortable easy battery life issue recommend']),
#        list(['', 'learn lesson year ', 'charge month ', 'good']),
#        list(['clasp fell losing lucky location phone day long return wast money']),
#        list(['considerably ', 'charger short cable length nice ', 'charger that']),
#        list(['bought ', 'wife ', 'display beautiful ', 'works ', 'lot']),
#        list(['bought sleep ', '', '', 'day remember pretty comfortable']),
#        list(['wife ', 'son ', 'love update tricky times ', '', '', 'good']),
#        list(['works protecting bump notice ', 'chip bit ', 'save breaking']),
#        list(['perfectly charge size smaller lot extra']),
#        list(['lose ', 'purchase care leaving ', 'weight gym']),
#        list(['time ', 'specially heart sens', 'lot track recommend']),
#        list(['magnetic charging cable ', 'meant ', '', 'nicely travel mount']),
#        list(['good solid ', 'bit clumsy magnet ', 'sturdy ', 'comfortable']),
#        list(['', 'friend sale ', 'great price ', 'absolutely highly']),
#        list(['bad ', 'finally caught steal love ', 'change great product']),
#        list(['purchase hope open battery']),
#        list(['track health ', 'lost lot weight awesome ', 'highly recommend ', '', 'perfect']),
#        list(['highly recommend ', 'size love recommend future buy']),
#        list(['good complimentary ', 'switch for']),
#        list(['love compare ', 'works perfect great ', 'exercise']),
#        list(['', 'daughter didnt ', 'feminine happy']),
#        list(['', 'younger ', '', 'fantastic ', 'price']),
#        list(['excellent sale ', 'opportunity ', 'buy purchase']),
#        list(['love working ', 'yard work enjoyable pair listen phone']),
#        list(['love convenient ', '', 'phone ', 'trade']),
#        list(['switched series fantastic upgrade ', 'worried knocking happy']),
#        list(['great product plan open ', 'close do', 'good']),
#        list(['reason ', '', '', 'working']),
#        list(['wasnt ', '', '', 'love ', '', '', '', 'day']),
#        list(['love great phone pocket ', 'working phone']),
#        list(['love easy ', 'paying ', 'wallet ease ', 'lot accessible wrist']),
#        list(['love ', 'older ', 'working great']),
#        list(['good wise ', 'battery life longer charge night ', 'wore day']),
#        list(['display feel standard ', 'battery life unbelievable']),
#        list(['', 'keeping task fitness time pandemic']),
#        list(['light weight ', 'accurate love accountability phone ', 'free now']),
#        list(['bought spare charger ', 'battery charger works great ', 'battery']),
#        list(['series ', 'recommend']),
#        list(['great series great battery life day ', 'day buy quick fast ', 'reliable']),
#        list(['glasses great eye strain ', 'sleep tracked charge recommend']),
#        list(['favorite phone perfect ', 'work because']),
#        list(['great device everyday battery life amazing ', 'store music ', 'great']),
#        list(['functionality glad didnt pay ', 'model because']),
#        list(['smart ', '', '', '', 'series bigger ', 'rounded awesome']),
#        list(['nice lots recommend product battery life good ', 'charge remain ', 'days']),
#        list(['strong nicely charge didnt and']),
#        list(['great ', 'days ', 'battery life basic comparable']),
#        list(['worn daily ionic dont ', 'lot ', '', 'device']),
#        list(['charging cable ', '', 'bought works ', 'price good buy ', 'recommend']),
#        list(['', '', '', 'long']),
#        list(['', 'view ', 'send performance price cheap for']),
#        list(['live ', 'whoop tracker love connected ', 'phone']),
#        list(['time hubby bought ', '', 'finally split']),
#        list(['great ', 'great price ', 'great highly recommend buy']),
#        list(['received day gift perfect compact device charge phone ', 'fast charging ', 'works']),
#        list(['lite great stay healthy price sleep monit', 'great']),
#        list(['gift ', 'comfortable wear happy']),
#        list(['partner wanting ', 'cant group']),
#        list(['love generation faster phone great worth money']),
#        list(['health fantastic worse ', 'galaxy active enjoy']),
#        list(['wear time charge ', 'classy ', 'fun comfortable ', 'easy links fit wrist']),
#        list(['', 'simple ', 'quick long ', 'unlock good']),
#        list(['daughter excited ', '', 'reaching exercise ', 'st', 'win win for']),
#        list(['', 'bit long compatible charger works series fast']),
#        list(['great smart love ', 'ease view concern scratching cracking']),
#        list(['love disadvantage ', 'couple ', '', 'battery long before']),
#        list(['big upgrade series ', 'lot cool ', 'series didnt ', 'battery life']),
#        list(['bar ', 'fitness ', 'style leave motivate active ', 'godsend']),
#        list(['love upgrade fir birthday series ', 'figured time upgrade love']),
#        list(['', '', 'great product ', 'great afraid hurt great replacement for']),
#        list(['daughter ', '', 'love daughter ', 'happy papa smile']),
#        list(['love long charge days dislike dress ', 'nice dress']),
#        list(['', 'husb', 'wear ', 'working garden lot']),
#        list(['love charge charge suddenly stopped working ', 'matter ', 'wouldnt work glad bought charge']),
#        list(['expect smart phone level ', 'android']),
#        list(['wife ', 'surprise charging adapter works perfectly ', 'damn shame ', 'buy']),
#        list(['small size charge short time ', 'working nice easy adjustment fit easy change']),
#        list(['series series love display ', 'series']),
#        list(['original cable ', 'wouldnt charge properly st', 'thickness ring doesnt charge properly']),
#        list(['stay charge times day ', 'store defective box']),
#        list(['', '', 'doesnt fit ', 'professional']),
#        list(['', 'inspire ', 'battery ', 'week ', 'rendering pretty useless']),
#        list(['ill love series ass geet']),
#        list(['love complaint battery day open recommend']),
#        list(['shipped paper unbelievable damage good job update works fine thankfully']),
#        list(['face real game changer ', '', 'previous version']),
#        list(['pretty good easy clean mild soap ', 'water perfectly happy purchase ', 'recommend']),
#        list(['nice design good magnet strong fall kind expensive ', 'good']),
#        list(['good protect ', 'hard ', 'easier ', 'cleaning']),
#        list(['visiting figure manual reference']),
#        list(['wife ', 'travel wont long loose charger replacement affordable ', 'works']),
#        list(['nice ', 'price bought ', 'wife ', 'handed daughter works']),
#        list(['easily ', '', 'caught plastic ', 'protect nicely']),
#        list(['works fine ', 'charging disappointment purchase separately included']),
#        list(['perfect addition sense ', 'easy ', 'active ', 'ecosystem reason']),
#        list(['bought love great lighting love charge phone ', 'night st', 'nicely built']),
#        list(['series met ', 'fitness target exercise incoming phone']),
#        list(['work long ', 'phone text ', '', 'soother cool']),
#        list(['', 'version slim ', '', 'big ', 'bulky whatsoever']),
#        list(['', 'time ', 'expect great dont havent bought sooner']),
#        list(['replacement ', 'charge buy replacement order ', 'pay additional shipping']),
#        list(['', 'day ', 'love ', 'doesnt feel bulky wrist feel']),
#        list(['great ', '', 'longer than']),
#        list(['love ionic ', '', 'expensive ', 'worked good']),
#        list(['great love col', 'buy expensive ', 'store buy']),
#        list(['bigger face ', 'dictation ', 'great product']),
#        list(['upgrade previous disappoint ', 'waterproof ', '', 'functional for']),
#        list(['series amazing super fast bright crisp ', 'clear oxygen sens', 'works great super easy set ', 'great product']),
#        list(['disappoint ', 'process buy quick ', 'easy']),
#        list(['love phone ', 'return bulky ', 'great']),
#        list(['perfect fit easy install durable comparable ', 'affordable glad purchase recommend']),
#        list(['sport loop ', '', 'favorite style lightweight comfortable sweatproof adjustable ', 'perfect fit']),
#        list(['interact day long returned upgrade series ', 'worth investment']),
#        list(['finally works great ways neighborhood everyday'])],
#       dtype=object)

# %%
print(type(processed_reviews))
# Out:
# <class 'numpy.ndarray'>

# %%
df1 = pd.DataFrame(processed_reviews)
df1.columns = ['Full Text']
df1.head()
# Out:
#                                            Full Text
# 0      [nephew fact , waterproof finding black deal]
# 1            [series amazing , , health , attention]
# 2           [gem durability , battery life day hunt]
# 3  [stopped charging , bummed buy , glad , faster...
# 4        [super work great , price highly recommend]

# %%
############## Check Terms ####################

#terms = ['easy to use', 'simple', 'straightforward', 'user-friendly', 'intuitive']

def checkterms(string, termsvalues):
    checkterm = False
    for i in range(len(termsvalues)):
        if (string.find(termsvalues[i]) >= 0):
            checkterm = True
    return checkterm
 
#checkterms('This is easy to use hello', terms)
# Out:
# True

# %%
############## Check Negators ####################
def checknegators(string):
    negatorvalues = ["ain't", "aren't", "cannot", "cant", "can't", "couldn't", "daren't", "didn't", 
                     "don't", "hasn't","haven't", "isn't", "mayn't","mightn't","mustn't","needn't",
                     "not","oughtn't","shan't","shouldn't","weren't", "won't", "wouldn't"]
    checknegator = False
    for i in range(len(negatorvalues)):
        if (string.find(negatorvalues[i]) >= 0):
            checknegator = True
    return checknegator
 
#checknegators('This is hello simple')
# Out:
# False

# %%
############## Encode Reviews####################

# %%
#myArray = ['easy to use watch', 'health ', 'attention']

#ease_of_use_terms = ['simple', 'easy to use',  'straightforward', 'user-friendly', 'intuitive']


def encodereviews(reviewarray, qualityterms):
    encode = 0
    for i in reviewarray:
        if((checknegators(i) == False) and (checkterms(i, qualityterms) == True)):
            encode = 1
        else:
            continue
    return encode

# %%
#encodereviews(myArray, ease_of_use_terms)

# %%
df1["Ease of Use"] = ""
df1.head()
# Out:
#                                        Full Text Ease of Use
# 0  [nephew fact , waterproof finding black deal]
# 1        [series amazing , , health , attention]

# %%
ease_of_use_terms = ['easy to use', 'simple', 'straightforward', 'user-friendly', 'intuitive']

for i in range(len(df1['Full Text'])):
    #print(df1['Full Text'][i])
    if(encodereviews(df1['Full Text'][i], ease_of_use_terms) == 1):
        df1.at[i,'Ease of Use'] = 1
    else:
        df1.at[i,'Ease of Use'] = 0

# %%
df1
# Out:
#                                              Full Text Ease of Use
# 0        [nephew fact , waterproof finding black deal]           0
# 1              [series amazing , , health , attention]           0
# 2             [gem durability , battery life day hunt]           0
# 3    [stopped charging , bummed buy , glad , faster...           0
# 4          [super work great , price highly recommend]           0
# ..                                                 ...         ...
# 995                [love phone , return bulky , great]           0
# 996  [perfect fit easy install durable comparable ,...           0
# 997  [sport loop , , favorite style lightweight com...           0
# 998  [interact day long returned upgrade series , w...           0
# 999   [finally works great ways neighborhood everyday]           0
#
# [1000 rows x 2 columns]

# %%
df1.to_csv('out1.csv')

# %%
#ease_of_use_terms = ['easy to use', 'simple', 'straightforward', 'user-friendly', 'intuitive']
df1.loc[df1['Ease of Use'] == 1]
# Out:
#                                              Full Text Ease of Use
# 77         [love smart simple , , totally worth price]           1
# 109   [everyday exception , , works , super intuitive]           1
# 111    [love , simplicity amazing simple , understand]           1
# 125  [, great , affordable alternative style simple...           1
# 245  [sharp simple clean design easy perfectly , wr...           1
# 332  [sharp simple clean design charge perfectly , ...           1
# 345         [, , , , decided process simple , happier]           1
# 346              [simple box feel phone properly even]           1
# 449         [worth buy simple beautiful , great , and]           1
# 484               [love price simple bought , stretch]           1
# 496  [simple , sophisticated comfortable , , sophis...           1
# 528  [sharp simple clean design easy perfectly , co...           1
# 661                        [simple lot option company]           1
# 706  [series simple navigation tricky times , bough...           1
# 864  [lot missing couple , , price match connection...           1
# 947              [, simple , quick long , unlock good]           1
